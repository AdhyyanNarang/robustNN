# %%
import pandas as pd

# %%
df = pd.read_excel("results.xlsx")

# %%
df
# Out:
#     Unnamed: 0  epochs  op_reg  learning_rate adv_train_flag  \
# 0            0     250  0.0007         0.0003        Regular
# 1            1       1  0.0000         0.0030        Regular
# 2            2       1  0.0000         0.0030        Regular
# 3            3      10  0.0000         0.0030        Regular
# 4            4      10  0.0000         0.0030        Regular
# 5            5      10  0.0000         0.0030        Regular
# 6            6      10  0.0000         0.0030        Regular
# 7            7      10  0.0000         0.0030        Regular
# 8            8      10  0.0000         0.0030        Regular
# 9            9      10  0.0000         0.0030        Regular
# 10          10       3  0.0000         0.0030        Regular
# 11          11       3  0.0000         0.0030        Regular
# 12          12      30  0.0010         0.0030        Regular
# 13          13      30  0.0050         0.0030        Regular
# 14          14      70  0.0080         0.0030        Regular
# 15          15      30  0.0000         0.0030           FGSM
#
#                         activation  acc_reg  acc_fgsm  acc_pgd  loss_reg  \
# 0                          Sigmoid  93.1000   67.6000      NaN  0.200000
# 1                          sigmoid   0.7244    0.0532      NaN  0.815572
# 2                          sigmoid   0.7919    0.0581      NaN  0.692795
# 3                          sigmoid   0.9467    0.1215      NaN  0.213453
# 4                          sigmoid   0.9369    0.1234      NaN  0.254690
# 5                          sigmoid   0.9275    0.0682      NaN  0.297708
# 6                          sigmoid   0.9441    0.0200      NaN  0.246185
# 7                          sigmoid   0.9415    0.2319      NaN  0.255781
# 8                             Relu   0.9623    0.0397      NaN  0.163400
# 9                             Relu   0.9622    0.0629      NaN  0.162054
# 10                            Relu   0.9299    0.0392   0.0060  0.237050
# 11  <function relu at 0x117e589d8>   0.9531    0.0485   0.0134  0.171038
# 12  <function relu at 0x11ad159d8>   0.9658    0.2011   0.1812  0.145118
# 13  <function relu at 0x12008f9d8>   0.9586    0.2369   0.0370  0.142956
# 14  <function relu at 0x1240199d8>   0.9385    0.2345   0.0783  0.215417
# 15  <function relu at 0x11951f9d8>   0.9518    0.8099   0.4520  0.183008
#
#     loss_pgd  loss_fgsm               logdir           weights_path  \
# 0        NaN   0.800000                  NaN                    NaN
# 1        NaN   5.454380  logs/results_11.log                    NaN
# 2        NaN   4.691385  logs/results_13.log                    NaN
# 3        NaN   6.628881  logs/results_41.log                    NaN
# 4        NaN   6.354927  logs/results_42.log                    NaN
# 5        NaN   7.019248  logs/results_43.log                    NaN
# 6        NaN   8.873349  logs/results_44.log                    NaN
# 7        NaN   5.129439  logs/results_45.log                    NaN
# 8        NaN   8.993169  logs/results_46.log                    NaN
# 9        NaN  28.447481  logs/results_47.log                    NaN
# 10  6.775509   0.039200  logs/results_57.log  weights/model_57.ckpt
# 11  6.398705   0.048500  logs/results_58.log  weights/model_58.ckpt
# 12  5.327451   0.201100  logs/results_71.log  weights/model_71.ckpt
# 13  4.122503   0.236900  logs/results_72.log  weights/model_72.ckpt
# 14  4.516582   0.234500  logs/results_74.log  weights/model_74.ckpt
# 15  0.670216   0.809900  logs/results_75.log  weights/model_75.ckpt
#
#               tb_dir                                          Distances  \
# 0                NaN                                       (None, None)
# 1   tb/11/non_robust                                       (None, None)
# 2   tb/13/non_robust  (0.9306673, 0.6533018, 0.6531849, 0.6674277, 0...
# 3   tb/41/non_robust  (0.9239762, 0.65693253, 0.6067492, 0.6374461, ...
# 4   tb/42/non_robust  (0.9097431, 0.59459233, 0.6237213, 0.646627, 0...
# 5   tb/43/non_robust  (0.8931245, 0.56005055, 0.59760016, 0.57427925...
# 6   tb/44/non_robust  (0.938725, 0.6600768, 0.66170657, 0.6852295, 0...
# 7   tb/45/non_robust  (0.92154706, 0.6415282, 0.6576658, 0.6670158, ...
# 8   tb/46/non_robust  (13.717814, 18.26012, 24.893442, 31.145538, 29...
# 9   tb/47/non_robust  (13.70231, 18.81006, 24.938885, 29.81304, 33.9...
# 10  tb/57/non_robust  (7.4477954, 6.8025093, 7.2666335, 7.3556733, 8...
# 11  tb/58/non_robust  (7.135254, 7.887454, 7.845998, 8.052931, 8.588...
# 12  tb/71/non_robust  (5.475276, 12.719564, 18.869154, 27.198263, 26...
# 13  tb/72/non_robust  (2.139943, 3.496155, 3.843952, 5.1138744, 6.22...
# 14  tb/74/non_robust  (1.7076006, 2.5921235, 2.5732467, 3.4120953, 4...
# 15      tb/75/robust  (6.767173, 17.473831, 38.257633, 49.1879, 27.2...
#
#                                                 Norms
# 0                                        (None, None)
# 1                                        (None, None)
# 2   (<tf.Tensor 'model_non_robust/Max_8:0' shape=(...
# 3   (319.44058, 36.396854, 20.660694, 23.362183, 2...
# 4   (325.33728, 32.12922, 22.591274, 19.652607, 20...
# 5   (326.3446, 31.664152, 22.359634, 21.57176, 27....
# 6   (329.55527, 26.631884, 20.483023, 21.433125, 2...
# 7   (332.50662, 27.713497, 22.988976, 24.210987, 2...
# 8   (267.34714, 12.150078, 13.141031, 13.2189455, ...
# 9   (281.3783, 12.946939, 12.665519, 12.067004, 9....
# 10  (138.91463, 9.132495, 8.988977, 8.27085, 8.298...
# 11  (140.55019, 9.100359, 9.088696, 8.028114, 8.66...
# 12  (78.487724, 11.971958, 8.304008, 4.5321946, 2....
# 13  (29.190838, 5.508862, 3.9576876, 1.9097207, 1....
# 14  (23.436884, 4.6997, 2.8007762, 1.6223694, 1.46...
# 15  (131.64798, 17.081043, 17.57381, 15.574147, 13...

# %%
df['adv_train_flag'] = ["Regular"]*len(df)

# %%
df
# Out:
#    Unnamed: 0  epochs  op_reg  learning_rate adv_train_flag activation  \
# 0           0     250  0.0007         0.0003        Regular    Sigmoid
# 1           1       1  0.0000         0.0030        Regular    sigmoid
# 2           2       1  0.0000         0.0030        Regular    sigmoid
# 3           3      10  0.0000         0.0030        Regular    sigmoid
# 4           4      10  0.0000         0.0030        Regular    sigmoid
# 5           5      10  0.0000         0.0030        Regular    sigmoid
# 6           6      10  0.0000         0.0030        Regular    sigmoid
# 7           7      10  0.0000         0.0030        Regular    sigmoid
# 8           8      10  0.0000         0.0030        Regular       Relu
# 9           9      10  0.0000         0.0030        Regular       Relu
#
#    acc_reg  acc_robust  loss_reg  loss_robust               logdir  \
# 0  93.1000     67.6000  0.200000     0.800000                  NaN
# 1   0.7244      0.0532  0.815572     5.454380  logs/results_11.log
# 2   0.7919      0.0581  0.692795     4.691385  logs/results_13.log
# 3   0.9467      0.1215  0.213453     6.628881  logs/results_41.log
# 4   0.9369      0.1234  0.254690     6.354927  logs/results_42.log
# 5   0.9275      0.0682  0.297708     7.019248  logs/results_43.log
# 6   0.9441      0.0200  0.246185     8.873349  logs/results_44.log
# 7   0.9415      0.2319  0.255781     5.129439  logs/results_45.log
# 8   0.9623      0.0397  0.163400     8.993169  logs/results_46.log
# 9   0.9622      0.0629  0.162054    28.447481  logs/results_47.log
#
#              tb_dir                                          Distances  \
# 0               NaN                                       (None, None)
# 1  tb/11/non_robust                                       (None, None)
# 2  tb/13/non_robust  (0.9306673, 0.6533018, 0.6531849, 0.6674277, 0...
# 3  tb/41/non_robust  (0.9239762, 0.65693253, 0.6067492, 0.6374461, ...
# 4  tb/42/non_robust  (0.9097431, 0.59459233, 0.6237213, 0.646627, 0...
# 5  tb/43/non_robust  (0.8931245, 0.56005055, 0.59760016, 0.57427925...
# 6  tb/44/non_robust  (0.938725, 0.6600768, 0.66170657, 0.6852295, 0...
# 7  tb/45/non_robust  (0.92154706, 0.6415282, 0.6576658, 0.6670158, ...
# 8  tb/46/non_robust  (13.717814, 18.26012, 24.893442, 31.145538, 29...
# 9  tb/47/non_robust  (13.70231, 18.81006, 24.938885, 29.81304, 33.9...
#
#                                                Norms
# 0                                       (None, None)
# 1                                       (None, None)
# 2  (<tf.Tensor 'model_non_robust/Max_8:0' shape=(...
# 3  (319.44058, 36.396854, 20.660694, 23.362183, 2...
# 4  (325.33728, 32.12922, 22.591274, 19.652607, 20...
# 5  (326.3446, 31.664152, 22.359634, 21.57176, 27....
# 6  (329.55527, 26.631884, 20.483023, 21.433125, 2...
# 7  (332.50662, 27.713497, 22.988976, 24.210987, 2...
# 8  (267.34714, 12.150078, 13.141031, 13.2189455, ...
# 9  (281.3783, 12.946939, 12.665519, 12.067004, 9....

# %%
weights_path = [None]*len(df)

# %%
df.rename(columns = {"acc_robust": "acc_fgsm", "loss_robust": "loss_fgsm"})
# Out:
#    Unnamed: 0  epochs  op_reg  learning_rate adv_train_flag activation  \
# 0           0     250  0.0007         0.0003        Regular    Sigmoid
# 1           1       1  0.0000         0.0030        Regular    sigmoid
# 2           2       1  0.0000         0.0030        Regular    sigmoid
# 3           3      10  0.0000         0.0030        Regular    sigmoid
# 4           4      10  0.0000         0.0030        Regular    sigmoid
# 5           5      10  0.0000         0.0030        Regular    sigmoid
# 6           6      10  0.0000         0.0030        Regular    sigmoid
# 7           7      10  0.0000         0.0030        Regular    sigmoid
# 8           8      10  0.0000         0.0030        Regular       Relu
# 9           9      10  0.0000         0.0030        Regular       Relu
#
#    acc_reg  acc_fgsm  loss_reg  loss_fgsm               logdir  \
# 0  93.1000   67.6000  0.200000   0.800000                  NaN
# 1   0.7244    0.0532  0.815572   5.454380  logs/results_11.log
# 2   0.7919    0.0581  0.692795   4.691385  logs/results_13.log
# 3   0.9467    0.1215  0.213453   6.628881  logs/results_41.log
# 4   0.9369    0.1234  0.254690   6.354927  logs/results_42.log
# 5   0.9275    0.0682  0.297708   7.019248  logs/results_43.log
# 6   0.9441    0.0200  0.246185   8.873349  logs/results_44.log
# 7   0.9415    0.2319  0.255781   5.129439  logs/results_45.log
# 8   0.9623    0.0397  0.163400   8.993169  logs/results_46.log
# 9   0.9622    0.0629  0.162054  28.447481  logs/results_47.log
#
#              tb_dir                                          Distances  \
# 0               NaN                                       (None, None)
# 1  tb/11/non_robust                                       (None, None)
# 2  tb/13/non_robust  (0.9306673, 0.6533018, 0.6531849, 0.6674277, 0...
# 3  tb/41/non_robust  (0.9239762, 0.65693253, 0.6067492, 0.6374461, ...
# 4  tb/42/non_robust  (0.9097431, 0.59459233, 0.6237213, 0.646627, 0...
# 5  tb/43/non_robust  (0.8931245, 0.56005055, 0.59760016, 0.57427925...
# 6  tb/44/non_robust  (0.938725, 0.6600768, 0.66170657, 0.6852295, 0...
# 7  tb/45/non_robust  (0.92154706, 0.6415282, 0.6576658, 0.6670158, ...
# 8  tb/46/non_robust  (13.717814, 18.26012, 24.893442, 31.145538, 29...
# 9  tb/47/non_robust  (13.70231, 18.81006, 24.938885, 29.81304, 33.9...
#
#                                                Norms
# 0                                       (None, None)
# 1                                       (None, None)
# 2  (<tf.Tensor 'model_non_robust/Max_8:0' shape=(...
# 3  (319.44058, 36.396854, 20.660694, 23.362183, 2...
# 4  (325.33728, 32.12922, 22.591274, 19.652607, 20...
# 5  (326.3446, 31.664152, 22.359634, 21.57176, 27....
# 6  (329.55527, 26.631884, 20.483023, 21.433125, 2...
# 7  (332.50662, 27.713497, 22.988976, 24.210987, 2...
# 8  (267.34714, 12.150078, 13.141031, 13.2189455, ...
# 9  (281.3783, 12.946939, 12.665519, 12.067004, 9....

# %%
df.insert(11, "weights_path", weights_path, True)

# %%
df.insert(9, "loss_pgd", weights_path, True)

# %%
df = df.rename(columns = {"acc_robust": "acc_fgsm", "loss_robust": "loss_fgsm"})

# %%
df
# Out:
#    Unnamed: 0  epochs  op_reg  learning_rate adv_train_flag activation  \
# 0           0     250  0.0007         0.0003        Regular    Sigmoid
# 1           1       1  0.0000         0.0030        Regular    sigmoid
# 2           2       1  0.0000         0.0030        Regular    sigmoid
# 3           3      10  0.0000         0.0030        Regular    sigmoid
# 4           4      10  0.0000         0.0030        Regular    sigmoid
# 5           5      10  0.0000         0.0030        Regular    sigmoid
# 6           6      10  0.0000         0.0030        Regular    sigmoid
# 7           7      10  0.0000         0.0030        Regular    sigmoid
# 8           8      10  0.0000         0.0030        Regular       Relu
# 9           9      10  0.0000         0.0030        Regular       Relu
#
#    acc_reg  acc_fgsm  loss_reg loss_pgd  loss_fgsm               logdir  \
# 0  93.1000   67.6000  0.200000     None   0.800000                  NaN
# 1   0.7244    0.0532  0.815572     None   5.454380  logs/results_11.log
# 2   0.7919    0.0581  0.692795     None   4.691385  logs/results_13.log
# 3   0.9467    0.1215  0.213453     None   6.628881  logs/results_41.log
# 4   0.9369    0.1234  0.254690     None   6.354927  logs/results_42.log
# 5   0.9275    0.0682  0.297708     None   7.019248  logs/results_43.log
# 6   0.9441    0.0200  0.246185     None   8.873349  logs/results_44.log
# 7   0.9415    0.2319  0.255781     None   5.129439  logs/results_45.log
# 8   0.9623    0.0397  0.163400     None   8.993169  logs/results_46.log
# 9   0.9622    0.0629  0.162054     None  28.447481  logs/results_47.log
#
#   weights_path            tb_dir  \
# 0         None               NaN
# 1         None  tb/11/non_robust
# 2         None  tb/13/non_robust
# 3         None  tb/41/non_robust
# 4         None  tb/42/non_robust
# 5         None  tb/43/non_robust
# 6         None  tb/44/non_robust
# 7         None  tb/45/non_robust
# 8         None  tb/46/non_robust
# 9         None  tb/47/non_robust
#
#                                            Distances  \
# 0                                       (None, None)
# 1                                       (None, None)
# 2  (0.9306673, 0.6533018, 0.6531849, 0.6674277, 0...
# 3  (0.9239762, 0.65693253, 0.6067492, 0.6374461, ...
# 4  (0.9097431, 0.59459233, 0.6237213, 0.646627, 0...
# 5  (0.8931245, 0.56005055, 0.59760016, 0.57427925...
# 6  (0.938725, 0.6600768, 0.66170657, 0.6852295, 0...
# 7  (0.92154706, 0.6415282, 0.6576658, 0.6670158, ...
# 8  (13.717814, 18.26012, 24.893442, 31.145538, 29...
# 9  (13.70231, 18.81006, 24.938885, 29.81304, 33.9...
#
#                                                Norms
# 0                                       (None, None)
# 1                                       (None, None)
# 2  (<tf.Tensor 'model_non_robust/Max_8:0' shape=(...
# 3  (319.44058, 36.396854, 20.660694, 23.362183, 2...
# 4  (325.33728, 32.12922, 22.591274, 19.652607, 20...
# 5  (326.3446, 31.664152, 22.359634, 21.57176, 27....
# 6  (329.55527, 26.631884, 20.483023, 21.433125, 2...
# 7  (332.50662, 27.713497, 22.988976, 24.210987, 2...
# 8  (267.34714, 12.150078, 13.141031, 13.2189455, ...
# 9  (281.3783, 12.946939, 12.665519, 12.067004, 9....

# %%
df.insert(8, "acc_pgd", weights_path, True)

# %%
df
# Out:
#    Unnamed: 0  epochs  op_reg  learning_rate adv_train_flag activation  \
# 0           0     250  0.0007         0.0003        Regular    Sigmoid
# 1           1       1  0.0000         0.0030        Regular    sigmoid
# 2           2       1  0.0000         0.0030        Regular    sigmoid
# 3           3      10  0.0000         0.0030        Regular    sigmoid
# 4           4      10  0.0000         0.0030        Regular    sigmoid
# 5           5      10  0.0000         0.0030        Regular    sigmoid
# 6           6      10  0.0000         0.0030        Regular    sigmoid
# 7           7      10  0.0000         0.0030        Regular    sigmoid
# 8           8      10  0.0000         0.0030        Regular       Relu
# 9           9      10  0.0000         0.0030        Regular       Relu
#
#    acc_reg  acc_fgsm acc_pgd  loss_reg loss_pgd  loss_fgsm  \
# 0  93.1000   67.6000    None  0.200000     None   0.800000
# 1   0.7244    0.0532    None  0.815572     None   5.454380
# 2   0.7919    0.0581    None  0.692795     None   4.691385
# 3   0.9467    0.1215    None  0.213453     None   6.628881
# 4   0.9369    0.1234    None  0.254690     None   6.354927
# 5   0.9275    0.0682    None  0.297708     None   7.019248
# 6   0.9441    0.0200    None  0.246185     None   8.873349
# 7   0.9415    0.2319    None  0.255781     None   5.129439
# 8   0.9623    0.0397    None  0.163400     None   8.993169
# 9   0.9622    0.0629    None  0.162054     None  28.447481
#
#                 logdir weights_path            tb_dir  \
# 0                  NaN         None               NaN
# 1  logs/results_11.log         None  tb/11/non_robust
# 2  logs/results_13.log         None  tb/13/non_robust
# 3  logs/results_41.log         None  tb/41/non_robust
# 4  logs/results_42.log         None  tb/42/non_robust
# 5  logs/results_43.log         None  tb/43/non_robust
# 6  logs/results_44.log         None  tb/44/non_robust
# 7  logs/results_45.log         None  tb/45/non_robust
# 8  logs/results_46.log         None  tb/46/non_robust
# 9  logs/results_47.log         None  tb/47/non_robust
#
#                                            Distances  \
# 0                                       (None, None)
# 1                                       (None, None)
# 2  (0.9306673, 0.6533018, 0.6531849, 0.6674277, 0...
# 3  (0.9239762, 0.65693253, 0.6067492, 0.6374461, ...
# 4  (0.9097431, 0.59459233, 0.6237213, 0.646627, 0...
# 5  (0.8931245, 0.56005055, 0.59760016, 0.57427925...
# 6  (0.938725, 0.6600768, 0.66170657, 0.6852295, 0...
# 7  (0.92154706, 0.6415282, 0.6576658, 0.6670158, ...
# 8  (13.717814, 18.26012, 24.893442, 31.145538, 29...
# 9  (13.70231, 18.81006, 24.938885, 29.81304, 33.9...
#
#                                                Norms
# 0                                       (None, None)
# 1                                       (None, None)
# 2  (<tf.Tensor 'model_non_robust/Max_8:0' shape=(...
# 3  (319.44058, 36.396854, 20.660694, 23.362183, 2...
# 4  (325.33728, 32.12922, 22.591274, 19.652607, 20...
# 5  (326.3446, 31.664152, 22.359634, 21.57176, 27....
# 6  (329.55527, 26.631884, 20.483023, 21.433125, 2...
# 7  (332.50662, 27.713497, 22.988976, 24.210987, 2...
# 8  (267.34714, 12.150078, 13.141031, 13.2189455, ...
# 9  (281.3783, 12.946939, 12.665519, 12.067004, 9....

# %%
df.to_excel("results.xlsx", index = False)

# %%
# Out:
#    Unnamed: 0  epochs  op_reg  learning_rate adv_train_flag activation  \
# 0           0     250  0.0007         0.0003        Regular    Sigmoid
# 1           1       1  0.0000         0.0030        Regular    sigmoid
# 2           2       1  0.0000         0.0030        Regular    sigmoid
# 3           3      10  0.0000         0.0030        Regular    sigmoid
# 4           4      10  0.0000         0.0030        Regular    sigmoid
# 5           5      10  0.0000         0.0030        Regular    sigmoid
# 6           6      10  0.0000         0.0030        Regular    sigmoid
# 7           7      10  0.0000         0.0030        Regular    sigmoid
# 8           8      10  0.0000         0.0030        Regular       Relu
# 9           9      10  0.0000         0.0030        Regular       Relu
#
#    acc_reg  acc_fgsm acc_pgd  loss_reg loss_pgd  loss_fgsm  \
# 0  93.1000   67.6000    None  0.200000     None   0.800000
# 1   0.7244    0.0532    None  0.815572     None   5.454380
# 2   0.7919    0.0581    None  0.692795     None   4.691385
# 3   0.9467    0.1215    None  0.213453     None   6.628881
# 4   0.9369    0.1234    None  0.254690     None   6.354927
# 5   0.9275    0.0682    None  0.297708     None   7.019248
# 6   0.9441    0.0200    None  0.246185     None   8.873349
# 7   0.9415    0.2319    None  0.255781     None   5.129439
# 8   0.9623    0.0397    None  0.163400     None   8.993169
# 9   0.9622    0.0629    None  0.162054     None  28.447481
#
#                 logdir weights_path            tb_dir  \
# 0                  NaN         None               NaN
# 1  logs/results_11.log         None  tb/11/non_robust
# 2  logs/results_13.log         None  tb/13/non_robust
# 3  logs/results_41.log         None  tb/41/non_robust
# 4  logs/results_42.log         None  tb/42/non_robust
# 5  logs/results_43.log         None  tb/43/non_robust
# 6  logs/results_44.log         None  tb/44/non_robust
# 7  logs/results_45.log         None  tb/45/non_robust
# 8  logs/results_46.log         None  tb/46/non_robust
# 9  logs/results_47.log         None  tb/47/non_robust
#
#                                            Distances  \
# 0                                       (None, None)
# 1                                       (None, None)
# 2  (0.9306673, 0.6533018, 0.6531849, 0.6674277, 0...
# 3  (0.9239762, 0.65693253, 0.6067492, 0.6374461, ...
# 4  (0.9097431, 0.59459233, 0.6237213, 0.646627, 0...
# 5  (0.8931245, 0.56005055, 0.59760016, 0.57427925...
# 6  (0.938725, 0.6600768, 0.66170657, 0.6852295, 0...
# 7  (0.92154706, 0.6415282, 0.6576658, 0.6670158, ...
# 8  (13.717814, 18.26012, 24.893442, 31.145538, 29...
# 9  (13.70231, 18.81006, 24.938885, 29.81304, 33.9...
#
#                                                Norms
# 0                                       (None, None)
# 1                                       (None, None)
# 2  (<tf.Tensor 'model_non_robust/Max_8:0' shape=(...
# 3  (319.44058, 36.396854, 20.660694, 23.362183, 2...
# 4  (325.33728, 32.12922, 22.591274, 19.652607, 20...
# 5  (326.3446, 31.664152, 22.359634, 21.57176, 27....
# 6  (329.55527, 26.631884, 20.483023, 21.433125, 2...
# 7  (332.50662, 27.713497, 22.988976, 24.210987, 2...
# 8  (267.34714, 12.150078, 13.141031, 13.2189455, ...
# 9  (281.3783, 12.946939, 12.665519, 12.067004, 9....
