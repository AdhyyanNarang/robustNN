# %%
import pandas as pd

# %%
df = pd.read_excel("results.xlsx")

# %%
df
# Out:
#     Unnamed: 0  epochs  op_reg  learning_rate training_type  pgd_train_eps  \
# 0            0     250  0.0007         0.0003       Regular            NaN
# 1            1       1  0.0000         0.0030       Regular            NaN
# 2            2       1  0.0000         0.0030       Regular            NaN
# 3            3      10  0.0000         0.0030       Regular            NaN
# 4            4      10  0.0000         0.0030       Regular            NaN
# 5            5      10  0.0000         0.0030       Regular            NaN
# 6            6      10  0.0000         0.0030       Regular            NaN
# 7            7      10  0.0000         0.0030       Regular            NaN
# 8            8      10  0.0000         0.0030       Regular            NaN
# 9            9      10  0.0000         0.0030       Regular            NaN
# 10          10       3  0.0000         0.0030       Regular            NaN
# ...

# %%
empty_col = [None]*len(df)

# %%
df.insert(5, "pgd_train_eps", empty_col, True)
#df.insert(6, "pgd_train_num_iter", empty_col, True)

# %%
df
# Out:
#     Unnamed: 0  epochs  op_reg  learning_rate training_type pgd_train_eps  \
# 0            0     250  0.0007         0.0003       Regular          None
# 1            1       1  0.0000         0.0030       Regular          None
# 2            2       1  0.0000         0.0030       Regular          None
# 3            3      10  0.0000         0.0030       Regular          None
# 4            4      10  0.0000         0.0030       Regular          None
# 5            5      10  0.0000         0.0030       Regular          None
# 6            6      10  0.0000         0.0030       Regular          None
# 7            7      10  0.0000         0.0030       Regular          None
# 8            8      10  0.0000         0.0030       Regular          None
# 9            9      10  0.0000         0.0030       Regular          None
# 10          10       3  0.0000         0.0030       Regular          None
# 11          11       3  0.0000         0.0030       Regular          None
# ...

# %%
df = df.rename(columns = {"adv_train_flag": "training_type"})

# %%
df.to_excel("results.xlsx", index = False)

# %%
df
# Out:
#     Unnamed: 0  epochs  op_reg  learning_rate training_type pgd_train_eps  \
# 0            0     250  0.0007         0.0003       Regular          None
# 1            1       1  0.0000         0.0030       Regular          None
# 2            2       1  0.0000         0.0030       Regular          None
# 3            3      10  0.0000         0.0030       Regular          None
# 4            4      10  0.0000         0.0030       Regular          None
# 5            5      10  0.0000         0.0030       Regular          None
# 6            6      10  0.0000         0.0030       Regular          None
# 7            7      10  0.0000         0.0030       Regular          None
# 8            8      10  0.0000         0.0030       Regular          None
# 9            9      10  0.0000         0.0030       Regular          None
# 10          10       3  0.0000         0.0030       Regular          None
# 11          11       3  0.0000         0.0030       Regular          None
# ...
