# %%
#Imports
import logging
import os, random, time, sys
import numpy as np
import tensorflow as tf
import tensorflow.contrib.layers as layers
sys.path.append('../')
sys.path.append('../util/')
import feedforward_robust as ffr
import ipdb
from mnist_corruption import *
from util import *

#Read the counter
ctr_file = "counter.txt"
f = open(ctr_file, 'r')
counter = f.readline()
f.close()

counter = 1 + int(counter)
f = open(ctr_file,'w')
f.write('{}'.format(counter))
f.close()
logfile = "logs/results_" + str(counter) + ".log"

logger = logging.getLogger("robustness")
logger.setLevel(logging.DEBUG)
fh = logging.FileHandler(logfile)
fh.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
fh.setFormatter(formatter)
logger.addHandler(fh)
logger.addHandler(logging.StreamHandler())
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0918 23:19:36.749987 4654548416 deprecation_wrapper.py:119] From /usr/local/lib/python3.7/site-packages/cleverhans/utils_tf.py:341: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#Setup - Dataset stuff
dataset, input_shape, num_classes = get_dataset()
x_train_flat, y_train = dataset[0] 
x_test_flat, y_test = dataset[1] 
hidden_sizes = [32,32,32,32,32,32,32]

# %%
x_train_flat.shape
# Out:
# (60000, 784)

# %%
def plot_singular_values(matrix, idx, title):
    _, sig, V = np.linalg.svd(matrix)
    plt.plot(range(len(sig)), sig, label = "Layer number %d" %idx)
    plt.legend(loc = 'upper right')
    plt.title(title)
    return sig

# %%
def regular_training(config_inp):
    eps_train = config_inp['eps_train'] 
    eps_test = config_inp['eps_test'] 
    tensorboard_dir = config_inp['tensorboard_dir'] 
    weights_dir = config_inp['weights_dir']
    load_counter = config_inp['load_counter'] 
    sigma = config_inp['sigma']
    scope_name = config_inp['scope_name']
    
    with tf.variable_scope(scope_name, reuse = tf.AUTO_REUSE) as scope:
        sess = tf.Session()
        logdir = tensorboard_dir + str(counter) + "/non_robust"

        #Create, train and test model
        writer = tf.summary.FileWriter(logdir)
        model = ffr.RobustMLP(input_shape, hidden_sizes, num_classes, writer = writer, scope = scope_name, logger = logger, sigma =sigma)
        logger.info("Created model successfully. Now going to load weights")
        
        #Restore weights
        weights, biases = model.get_weights()
        weights_exp = weights + biases
        saver = tf.train.Saver(weights_exp)
        weights_path = saver.restore(sess, weights_dir + "model_" + str(load_counter) + ".ckpt")

        writer.add_graph(sess.graph)

        loss_reg, acc_reg = model.evaluate(sess, x_test_flat, y_test)
        logger.info("----Regular test accuracy and loss ----")
        logger.info((loss_reg, acc_reg))

        
        with tf.variable_scope("testing_benign") as scope:
            loss_reg, acc_reg = model.evaluate(sess, x_test_flat, y_test)
            logger.info("----Regular test accuracy and loss ----")
            logger.info((loss_reg, acc_reg))


        with tf.variable_scope("testing_adversarial") as scope:
            loss_fgsm, acc_fgsm = model.adv_evaluate(sess, x_test_flat, y_test, eps_test, pgd = False)
            logger.info("----FGSM test accuracy and loss ----")
            logger.info((loss_fgsm, acc_fgsm))
            x_test_flat_adv = model.fgsm_np(sess, x_test_flat, y_test, eps_test)
    return model, sess

# %%
def hybrid_training(config_inp):
    eps_train = config_inp['eps_train'] 
    eps_test = config_inp['eps_test'] 
    tensorboard_dir = config_inp['tensorboard_dir'] 
    weights_dir = config_inp['weights_dir']
    load_counter_non_robust = config_inp['load_counter_non_robust'] 
    load_counter_robust = config_inp['load_counter_robust']
    sigma = config_inp['sigma']
    scope_name = config_inp['scope_name']
    should_slash = config_inp['should_slash']
    slash_factor = config_inp['slash_factor']
    
    with tf.variable_scope(scope_name, reuse = tf.AUTO_REUSE) as scope:
        sess = tf.Session()
        logdir = tensorboard_dir + str(counter)

        #Create, train and test model
        writer = tf.summary.FileWriter(logdir)
        model = ffr.RobustMLP(input_shape, hidden_sizes, num_classes, writer = writer, scope = scope_name, logger = logger, sigma =sigma)
        feed_dict = {model.x: x_train_flat, model.y: y_train}
        sess.run(tf.global_variables_initializer(), feed_dict = feed_dict)
        logger.info("Created model successfully. Now going to load weights")
        
        #Restore all weights from non-robust
        weights, biases = model.get_weights()
        weights_exp = weights + biases
        saver = tf.train.Saver(weights_exp)
        weights_path = saver.restore(sess, weights_dir + "model_" + str(load_counter_non_robust) + ".ckpt")
        
        #Optionally slash weights
        if should_slash:
            model.slash_weights(sess, slash_factor)
            logger.info("Successfully slashed weights")
        
        logger.info("Successfully restored weights from non rob model.")

        #Restore the first and last layer from the robust model
        weights, biases = model.get_weights()
        selected_vars = [weights[0]] + [weights[-1]] + [biases[0]] + [biases[-1]]
        saver = tf.train.Saver(selected_vars)
        weights_path_rob = saver.restore(sess, weights_dir + "model_" + str(load_counter_robust) + ".ckpt")
        
        logger.info("Successfully restored weights from rob model.")
        
        #Run one epoch to try to make the weights more compatible with each other
        
        model.fit(sess, x_train_flat[0:10000], y_train[0:10000], training_epochs = 1, reg = 0, lr =3e-3)
        logger.info("Trained one epoch to attempt to make weights from different models compatible")
        
        #writer.add_graph(sess.graph)
        loss_reg, acc_reg = model.evaluate(sess, x_test_flat, y_test)
        logger.info("----Regular test accuracy and loss ----")
        logger.info((loss_reg, acc_reg))

        logger.info("Evaluating on FGSM points now.")
        loss_fgsm, acc_fgsm = model.adv_evaluate(sess, x_test_flat, y_test, eps_test, pgd = False)
        logger.info("----FGSM test accuracy and loss ----")
        logger.info((loss_fgsm, acc_fgsm))
        x_test_flat_adv = model.fgsm_np(sess, x_test_flat, y_test, eps_test)
    
        logger.info("Evaluating on PGD points now.")
        loss_pgd, acc_pgd = model.adv_evaluate(sess, x_test_flat, y_test, eps_test, pgd = True, eta=1e-2, num_iter = 40)
        logger.info("----PGD test accuracy and loss ----")
        logger.info((loss_pgd , acc_pgd))
        
    return model, sess

# %%
def adversarial_training(config):
    eps_train = config['eps_train'] 
    eps_test = config['eps_test'] 
    tensorboard_dir = config['tensorboard_dir'] 
    weights_dir = config['weights_dir']
    load_counter = config['load_counter'] 
    sigma = config['sigma']
    scope_name_rob = config['scope_name']
    sess = tf.Session()
    hidden_sizes = [32,32,32,32,32,32,32]
    
    dataset = ((x_train_flat, y_train), (x_test_flat, y_test))

    with tf.variable_scope(scope_name_rob, reuse = tf.AUTO_REUSE) as scope:
        tmp = set(tf.all_variables())
        logdir = tensorboard_dir + str(counter) + "/robust"
        writer_robust = tf.summary.FileWriter(logdir)
        logger.info("Adversarial Training")
        robust_model = ffr.RobustMLP(input_shape, hidden_sizes, num_classes, writer = writer_robust, scope = scope_name_rob, logger = logger, sigma = sigma)
        
        sess.run(tf.initialize_variables(set(tf.all_variables()) - tmp))
        robust_model.adv_fit(sess, x_train_flat, y_train, eps_train, lr = 3e-4, training_epochs = 20)

        print(robust_model.evaluate(sess, x_test_flat, y_test))
        print(robust_model.adv_evaluate(sess, x_test_flat, y_test, eps_test))
    return robust_model, sess

# %%
def activation_distance(activation_list):
    diff = []
    diff_norms = []
    for i in range(len(activation_list) - 1):
        difference = activation_list[i+1] - activation_list[i]
        diff.append(difference)
        diff_norms.append(np.linalg.norm(difference)/np.linalg.norm(activation_list[i]))
    return diff, diff_norms

# %%
def make_plot_acc_vs_eps_black_box(model_list, sess_list, eps_list, angle_list, legend_list, scope_list):
    x_test_2d = np.array([vec.reshape((28,28)) for vec in x_test_flat])
    fig = plt.figure(figsize = (10,10))
    ax_gb = fig.add_subplot(2, 2, 1)
    ax_rp = fig.add_subplot(2, 2, 2)
    ax_bw = fig.add_subplot(2, 2, 3)
    ax_rot = fig.add_subplot(2, 2, 4)
    
    for idx, model in enumerate(model_list):
        sess = sess_list[idx]
        legend = legend_list[idx]
        gb_acc = []
        rp_acc = []
        bw_acc = []
        rot_acc = []
        
        scope_name = scope_list[idx]
        
        for (idx, eps_test) in enumerate(eps_list):
            x_test_gaussian_blurred = flatten_mnist(gaussian_blurring(x_test_2d, eps_test))[0]
            x_test_random_pert = flatten_mnist(random_perturbation(x_test_2d, eps_test))[0]
            x_test_black_white = flatten_mnist(random_blackout_whiteout(x_test_2d, eps_test))[0]
            angle = angle_list[idx]
            x_test_rot = flatten_mnist(rotate(x_test_2d, angle))[0]
            
            #ipdb.set_trace()
            gb_acc.append(model.evaluate(sess, x_test_gaussian_blurred, y_test)[1])
            rp_acc.append(model.evaluate(sess, x_test_random_pert, y_test)[1])
            bw_acc.append(model.evaluate(sess, x_test_black_white, y_test)[1])
            rot_acc.append(model.evaluate(sess, x_test_rot, y_test)[1])

        ax_gb.plot(eps_list, gb_acc, label = legend)
        ax_rp.plot(eps_list, rp_acc, label = legend)
        ax_bw.plot(eps_list, bw_acc, label = legend)
        ax_rot.plot(angle_list, rot_acc, label = legend)
 
    ax_gb.set_title("Gaussian blurring")
    ax_rp.set_title("Random perturbation")
    ax_bw.set_title("Blackwhite")
    ax_rot.set_title("Rotation")
    
    plt.legend(loc = (2.5, 0.7))
    plt.show()
    return True

# %%
def make_plot_acc_vs_eps(model_list, sess_list, eps_list, legend_list, scope_list, pgd = False):
    fig = plt.figure()
    x_test_2d = [vec.reshape((28,28)) for vec in x_test_flat]
    
    for idx, model in enumerate(model_list):
        sess = sess_list[idx]
        legend = legend_list[idx]
        y_array = []
        scope_name = scope_list[idx]
        
        for eps_test in eps_list:
            if not pgd:
                _, acc_fgsm = model.adv_evaluate(sess, x_test_flat, y_test, eps_test, pgd = False)
                y_array.append(acc_fgsm)
            else:
                with tf.variable_scope(scope_name, reuse = tf.AUTO_REUSE) as scope:
                    _, acc_pgd = model.adv_evaluate(sess, x_test_flat, y_test, eps_test, pgd = True, eta=1e-2, num_iter = 50)
                    y_array.append(acc_pgd)
                    
        plt.plot(eps_list, y_array, label = legend)
    
    plt.legend(loc = 1)
    plt.show()
    return True

# %%
def get_stats_all_models(model_list, sess_list, scope_list):
    
    eps_test = 0.1
    reg_evals = []
    adv_evals = []
    margins = []
    dphi_dxs = []
        
    for idx, model in enumerate(model_list):
        sess = sess_list[idx]
        y_array = []
        scope_name = scope_list[idx]

        with tf.variable_scope(scope_name, reuse = tf.AUTO_REUSE) as scope:
            #Get dphi_dx
            dphi_dx_test = model.get_dphi_dx(sess, x_test_flat)[0]
            dphi_dxs.append(np.mean(np.abs(dphi_dx_test)))
            
            #Get reg_evals
            reg_evals.append(model.evaluate(sess, x_test_flat, y_test))
            
            #Get adv_evals
            adv_evals.append(model.adv_evaluate(sess, x_test_flat, y_test, eps_test, pgd = False))
            
            #Get margins
            x_test_feat_pert = model.attack_featurization_space(sess, x_test_flat, y_test, 1.0, 0.1, 200)
            loss_feat_adv, acc_feat_adv = model.evaluate_from_featurizations(sess, x_test_feat_pert, y_test)
            margins.append(acc_feat_adv)
            
    return reg_evals, adv_evals, margins, dphi_dxs

# %%
def make_dist_plot_all_models(model_list, sess_list, scope_list, legend_list, order):
    plt.figure()
    
    for idx, model in enumerate(model_list):
        sess = sess_list[idx]
        scope_name = scope_list[idx]
        legend = legend_list[idx]

        with tf.variable_scope(scope_name, reuse = tf.AUTO_REUSE) as scope:
            y_array = model.get_distance(sess, 0.10, x_test_flat, y_test, order = order)[0]
            plt.plot(range(len(y_array)), y_array, label = legend)
    
    plt.legend()
    plt.show()
    return True

# %%
scope_list = ["hybrid", "model_non_robust", ]

# %%
x_test_2d = [vec.reshape((28,28)) for vec in x_test_flat]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)


ax1.plot(range(10), range(10))
ax2.plot(range(10), range(10))

fig.show()
# Out:
# /usr/local/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %% [markdown]
# ### Trying out different corruptions

# %%
#Random trying out stuff
x_test_gaussian_blurred = gaussian_blurring(x_test_2d, 0.5)

# %%
x_test_rotated = rotate(x_test_2d, angle = 45)

# %%
plt.imshow(x_test_rotated[0], cmap = plt.cm.binary)

# %% [markdown]
# # Hybrid Training

# %%
config = {}
config['eps_train'] = 0.1
config['eps_test'] = 0.1
config['tensorboard_dir'] = "tb/"
config['weights_dir'] = "weights/"

config['load_counter_robust'] = 280
config['load_counter_non_robust'] = 282
config['should_slash'] = False
config['slash_factor'] = 0.70

config['sigma'] = tf.nn.relu

config['scope_name'] = "hybrid"

# %%
model_hybrid, sess_hybrid = hybrid_training(config)
# Out:
# Initialized instance variables of the robust model class
# I0918 23:19:40.792264 4654548416 feedforward_robust.py:30] Initialized instance variables of the robust model class
# W0918 23:19:40.794353 4654548416 deprecation_wrapper.py:119] From ../feedforward_robust.py:34: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Created placeholders for x and y
# I0918 23:19:40.831034 4654548416 feedforward_robust.py:36] Created placeholders for x and y
# W0918 23:19:40.832410 4654548416 deprecation_wrapper.py:119] From ../util.py:34: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0918 23:19:40.833055 4654548416 deprecation_wrapper.py:119] From ../util.py:34: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W0918 23:19:40.834885 4654548416 deprecation_wrapper.py:119] From ../util.py:36: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0918 23:19:40.963680 4654548416 deprecation_wrapper.py:119] From ../util.py:40: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# Created layers and tensor for logits
# I0918 23:19:41.075982 4654548416 feedforward_robust.py:40] Created layers and tensor for logits
# W0918 23:19:41.077250 4654548416 deprecation.py:323] From ../feedforward_robust.py:42: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0918 23:19:41.149482 4654548416 deprecation_wrapper.py:119] From ../feedforward_robust.py:44: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# Added loss computation to the graph
# I0918 23:19:41.152657 4654548416 feedforward_robust.py:45] Added loss computation to the graph
# Added accuracy computation to the graph
# I0918 23:19:41.161102 4654548416 feedforward_robust.py:49] Added accuracy computation to the graph
# Model graph was created
# I0918 23:19:41.163660 4654548416 feedforward_robust.py:52] Model graph was created
# W0918 23:19:41.165614 4654548416 deprecation_wrapper.py:119] From ../feedforward_robust.py:53: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# Created model successfully. Now going to load weights
# I0918 23:19:41.572271 4654548416 <ipython-input-7-ee235a87947b>:22] Created model successfully. Now going to load weights
# W0918 23:19:41.599456 4654548416 deprecation.py:323] From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Successfully restored weights from non rob model.
# I0918 23:19:41.698178 4654548416 <ipython-input-7-ee235a87947b>:35] Successfully restored weights from non rob model.
# Successfully restored weights from rob model.
# I0918 23:19:41.750085 4654548416 <ipython-input-7-ee235a87947b>:43] Successfully restored weights from rob model.
# W0918 23:19:41.793525 4654548416 deprecation.py:323] From ../feedforward_robust.py:436: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# W0918 23:19:41.794420 4654548416 deprecation_wrapper.py:119] From ../feedforward_robust.py:437: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0918 23:19:42.164453 4654548416 deprecation.py:323] From /usr/local/lib/python3.7/site-packages/tensorflow/python/util/tf_should_use.py:193: initialize_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.variables_initializer` instead.
# Epoch: 0001    cost: 1.353783539
# I0918 23:19:43.069230 4654548416 feedforward_robust.py:414] Epoch: 0001    cost: 1.353783539
# Accuracy on batch: 0.875000
# I0918 23:19:43.070541 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.875000
# Optimization Finished!
# I0918 23:19:43.073641 4654548416 feedforward_robust.py:416] Optimization Finished!
# Final Train Loss 0.574919
# I0918 23:19:43.132245 4654548416 feedforward_robust.py:424] Final Train Loss 0.574919
# Final Train Accuracy 0.812500:
# I0918 23:19:43.133523 4654548416 feedforward_robust.py:425] Final Train Accuracy 0.812500:
# Model was trained on benign data
# I0918 23:19:43.135572 4654548416 feedforward_robust.py:442] Model was trained on benign data
# Trained one epoch to attempt to make weights from different models compatible
# I0918 23:19:43.137769 4654548416 <ipython-input-7-ee235a87947b>:48] Trained one epoch to attempt to make weights from different models compatible
# Model was evaluated on benign data
# I0918 23:19:43.165511 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# ----Regular test accuracy and loss ----
# I0918 23:19:43.167086 4654548416 <ipython-input-7-ee235a87947b>:52] ----Regular test accuracy and loss ----
# (0.6153447, 0.8071)
# I0918 23:19:43.169927 4654548416 <ipython-input-7-ee235a87947b>:53] (0.6153447, 0.8071)
# Evaluating on FGSM points now.
# I0918 23:19:43.171173 4654548416 <ipython-input-7-ee235a87947b>:55] Evaluating on FGSM points now.
# Model is being evaluated on FGSM data
# I0918 23:19:43.371450 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# ----FGSM test accuracy and loss ----
# I0918 23:19:43.384564 4654548416 <ipython-input-7-ee235a87947b>:57] ----FGSM test accuracy and loss ----
# (2.5958252, 0.362)
# I0918 23:19:43.386373 4654548416 <ipython-input-7-ee235a87947b>:58] (2.5958252, 0.362)
# Evaluating on PGD points now.
# I0918 23:19:43.580595 4654548416 <ipython-input-7-ee235a87947b>:61] Evaluating on PGD points now.
# Model is being evaluated on PGD points generated using 0.010000 learning rate and 40 iterations
# I0918 23:19:43.582532 4654548416 feedforward_robust.py:365] Model is being evaluated on PGD points generated using 0.010000 learning rate and 40 iterations
# iteration: 0
# loss 0.787171
# iteration: 1
# loss 0.964062
# iteration: 2
# loss 1.153704
# iteration: 3
# loss 1.349437
# iteration: 4
# loss 1.550424
# iteration: 5
# loss 1.750918
# iteration: 6
# loss 1.948359
# iteration: 7
# loss 2.145344
# iteration: 8
# loss 2.335016
# iteration: 9
# loss 2.516565
# iteration: 10
# loss 2.690389
# iteration: 11
# loss 2.852589
# iteration: 12
# loss 3.005164
# iteration: 13
# loss 3.145811
# iteration: 14
# loss 3.271771
# iteration: 15
# loss 3.386966
# iteration: 16
# loss 3.488747
# iteration: 17
# loss 3.577561
# iteration: 18
# loss 3.652045
# iteration: 19
# loss 3.712682
# iteration: 20
# loss 3.763568
# iteration: 21
# loss 3.809395
# iteration: 22
# loss 3.849298
# iteration: 23
# loss 3.886914
# iteration: 24
# loss 3.918908
# iteration: 25
# loss 3.948093
# iteration: 26
# loss 3.974924
# iteration: 27
# loss 3.996488
# iteration: 28
# loss 4.018771
# iteration: 29
# loss 4.037120
# iteration: 30
# loss 4.055686
# iteration: 31
# loss 4.070808
# iteration: 32
# loss 4.084601
# iteration: 33
# loss 4.098678
# iteration: 34
# loss 4.108735
# iteration: 35
# loss 4.120658
# iteration: 36
# loss 4.129219
# iteration: 37
# loss 4.139625
# iteration: 38
# loss 4.146377
# iteration: 39
# This is to confirm that attack does not violate constraints
# I0918 23:19:48.528032 4654548416 feedforward_robust.py:209] This is to confirm that attack does not violate constraints
# Should be no more than eps
# I0918 23:19:48.532083 4654548416 feedforward_robust.py:210] Should be no more than eps
# 0.10000005352730845
# I0918 23:19:48.627364 4654548416 feedforward_robust.py:211] 0.10000005352730845
# loss 4.154283
# ----PGD test accuracy and loss ----
# I0918 23:19:48.656352 4654548416 <ipython-input-7-ee235a87947b>:63] ----PGD test accuracy and loss ----
# (4.154283, 0.2098)
# I0918 23:19:48.658658 4654548416 <ipython-input-7-ee235a87947b>:64] (4.154283, 0.2098)

# %%
dphi_dx_test_hybrid = model_hybrid.get_dphi_dx(sess_hybrid, x_test_flat)[0]

# %%
np.mean(np.abs(dphi_dx_test_hybrid))
# Out:
# 0.39415258

# %%
dpred_dx_test_hybrid = model_hybrid.get_pred_dx(sess_hybrid, x_test_flat)[0]
np.mean(np.abs(dpred_dx_test_hybrid))
# Out:
# 0.92792237

# %% [markdown]
# ## Regular Training

# %%
#tf.reset_default_graph()

# %%
config = {}
config['eps_train'] = 0.1
config['eps_test'] = 0.1
config['tensorboard_dir'] = "tb/"
config['weights_dir'] = "weights/"

config['load_counter'] = 222
config['sigma'] = tf.nn.relu

config['scope_name'] = "model_non_robust"

# %%
config['scope_name']
# Out:
# 'model_non_robust'

# %%
model_non_robust, sess_non_robust = regular_training(config)
# Out:
# Initialized instance variables of the robust model class
# I0918 23:19:49.582906 4654548416 feedforward_robust.py:30] Initialized instance variables of the robust model class
# Created placeholders for x and y
# I0918 23:19:49.586255 4654548416 feedforward_robust.py:36] Created placeholders for x and y
# Created layers and tensor for logits
# I0918 23:19:49.702119 4654548416 feedforward_robust.py:40] Created layers and tensor for logits
# Added loss computation to the graph
# I0918 23:19:49.721542 4654548416 feedforward_robust.py:45] Added loss computation to the graph
# Added accuracy computation to the graph
# I0918 23:19:49.729203 4654548416 feedforward_robust.py:49] Added accuracy computation to the graph
# Model graph was created
# I0918 23:19:49.731994 4654548416 feedforward_robust.py:52] Model graph was created
# Created model successfully. Now going to load weights
# I0918 23:19:49.736546 4654548416 <ipython-input-6-cc1dd069280b>:17] Created model successfully. Now going to load weights
# Model was evaluated on benign data
# I0918 23:19:49.982395 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# ----Regular test accuracy and loss ----
# I0918 23:19:49.983638 4654548416 <ipython-input-6-cc1dd069280b>:28] ----Regular test accuracy and loss ----
# (0.17380294, 0.9559)
# I0918 23:19:49.986810 4654548416 <ipython-input-6-cc1dd069280b>:29] (0.17380294, 0.9559)
# Model was evaluated on benign data
# I0918 23:19:50.011869 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# ----Regular test accuracy and loss ----
# I0918 23:19:50.013296 4654548416 <ipython-input-6-cc1dd069280b>:34] ----Regular test accuracy and loss ----
# (0.17380294, 0.9559)
# I0918 23:19:50.014653 4654548416 <ipython-input-6-cc1dd069280b>:35] (0.17380294, 0.9559)
# Model is being evaluated on FGSM data
# I0918 23:19:50.210683 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# ----FGSM test accuracy and loss ----
# I0918 23:19:50.225371 4654548416 <ipython-input-6-cc1dd069280b>:40] ----FGSM test accuracy and loss ----
# (6.6653485, 0.0579)
# I0918 23:19:50.226529 4654548416 <ipython-input-6-cc1dd069280b>:41] (6.6653485, 0.0579)

# %%
with tf.variable_scope(config['scope_name']) as scope:
    weights_non_robust = model_non_robust.get_weights_np(sess_non_robust)

# %%
#Original without regularization
sing_vals = []
for (idx, weight_matrix) in enumerate(weights_non_robust):
        sig = plot_singular_values(weight_matrix, idx, "Non robust model")
        sing_vals.append(sig)

# %%
#Regular points
acts = model_non_robust.get_activation(sess_non_robust, x_test_flat)
diff, diff_norm = activation_distance(acts)

#Adversarial points
x_test_flat_adv = model_non_robust.fgsm_np(sess_non_robust, x_test_flat, y_test, config['eps_test'])
#         4.13716650e+00,  2.17769861e+00,  8.31795216e-01,  2.62204337e+00,
#         1.98921776e+00, -9.85916436e-01, -1.54116631e+00,  5.21427998e-03,
#         1.20301533e+00,  9.38203514e-01,  1.03548956e+00,  3.28119516e-01,
#         4.65636402e-01, -5.69879055e-01, -1.20925140e+00, -1.53226495e+00,
#        -2.26409698e+00, -4.70060050e-01, -4.30382609e-01, -2.44482756e-01,
#        -6.23499870e-01,  3.74720991e-01, -6.04810417e-01, -3.52365911e-01,
#         1.41841620e-01, -1.70459464e-01, -2.66246915e-01, -1.89365953e-01,
#        -1.10225391e+00, -1.84237742e+00, -4.19678271e-01,  2.25492644e+00,
#         3.43214130e+00,  3.00772071e+00,  1.29697061e+00,  2.15943289e+00,
#         1.59717345e+00,  1.09013319e+00,  3.00925803e+00,  2.75167346e+00,
#         4.06935871e-01, -1.06019545e+00,  1.07495420e-01,  1.82868946e+00,
#         1.32400706e-01, -1.49801984e-01,  9.07749593e-01, -1.23275153e-01,
#        -4.99724835e-01,  2.31092620e+00,  1.58353329e-01, -3.76541823e-01,
#        -3.06747437e-01,  3.39852214e-01,  1.30050197e-01, -2.13305950e-01,
#         2.21341372e+00,  3.49542260e+00,  2.75314426e+00,  1.19597888e+00,
#         2.06528854e+00,  5.13729858e+00,  5.38020945e+00,  3.03855729e+00,
#         3.64858699e+00,  5.85819340e+00,  3.54237127e+00,  3.81304526e+00,
#         4.05813122e+00,  6.13955069e+00,  5.73213434e+00,  2.76121998e+00,
#         5.74016035e-01,  2.03859234e+00,  1.42924631e+00,  2.66918254e+00,
#        -1.89523891e-01,  2.97066364e-02,  1.77119136e-01,  3.10248345e-01],
#       dtype=float32)

# %%
dphi_dx_test_non_robust = dphi_dx_test
np.mean(np.abs(dphi_dx_test_non_robust))
# Out:
# 0.8664375

# %%
dpred_dx_test_non_robust = model_non_robust.get_pred_dx(sess_non_robust, x_test_flat)[0]
np.mean(np.abs(dpred_dx_test_non_robust))
# Out:
# 0.59841245

# %%
with tf.variable_scope(config['scope_name'], reuse = tf.AUTO_REUSE) as scope:
    x_test_feat_pert = model_non_robust.attack_featurization_space(sess_non_robust, x_test_flat, y_test, 1.0, 0.1, 200)
    loss_feat_adv, acc_feat_adv = model_non_robust.evaluate_from_featurizations(sess_non_robust, x_test_feat_pert, y_test)
    print(loss_feat_adv, acc_feat_adv)
# Out:
# Obtained featurizations
# I0918 23:19:51.855331 4654548416 feedforward_robust.py:216] Obtained featurizations
# W0918 23:19:51.862488 4654548416 deprecation.py:323] From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/variables.py:2618: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# Created feat adv graph
# I0918 23:19:52.115249 4654548416 feedforward_robust.py:224] Created feat adv graph
# iteration: 0
# loss 0.255138
# iteration: 1
# loss 0.330858
# iteration: 2
# loss 0.421669
# iteration: 3
# loss 0.528349
# iteration: 4
# loss 0.651319
# iteration: 5
# loss 0.789447
# iteration: 6
# loss 0.940789
# iteration: 7
# loss 1.102509
# iteration: 8
# loss 1.271232
# iteration: 9
# loss 1.442836
# iteration: 10
# loss 1.613476
# iteration: 187
# loss 2.596070
# iteration: 188
# loss 2.596070
# iteration: 189
# loss 2.596070
# iteration: 190
# loss 2.596070
# iteration: 191
# loss 2.596070
# iteration: 192
# loss 2.596070
# iteration: 193
# loss 2.596070
# iteration: 194
# loss 2.596070
# iteration: 195
# loss 2.596070
# iteration: 196
# loss 2.596070
# iteration: 197
# loss 2.596070
# iteration: 198
# loss 2.596070
# iteration: 199
# loss 2.596070
# 2.5960703 0.3237

# %%
adv_images_fgsm = model_non_robust.fgsm_np(sess_non_robust, x_test_flat, y_test, 0.10)

# %%
test_image = adv_images_fgsm[0]
two_d = test_image.reshape((28,28))
plt.imshow(two_d, cmap = plt.cm.binary)

# %%
"""
test_image = adv_images_pgd[0]
two_d = test_image.reshape((28,28))
plt.imshow(two_d, cmap = plt.cm.binary)
"""
# Out:
# '\ntest_image = adv_images_pgd[0]\ntwo_d = test_image.reshape((28,28))\nplt.imshow(two_d, cmap = plt.cm.binary)\n'

# %% [markdown]
# ## Trace regularization for first layer

# %%
#Config
config = {}
config['eps_train'] = 0.1
config['eps_test'] = 0.1
config['tensorboard_dir'] = "tb/"
config['weights_dir'] = "weights/"

config['load_counter'] = 121
config['sigma'] = tf.nn.relu

config['scope_name'] = "model_non_robust"

# %%
config['scope_name']
# Out:
# 'model_non_robust'

# %%
reg_model, sess_reg = regular_training(config)
# Out:
# Initialized instance variables of the robust model class
# I0918 23:19:54.005743 4654548416 feedforward_robust.py:30] Initialized instance variables of the robust model class
# Created placeholders for x and y
# I0918 23:19:54.009262 4654548416 feedforward_robust.py:36] Created placeholders for x and y
# Created layers and tensor for logits
# I0918 23:19:54.045433 4654548416 feedforward_robust.py:40] Created layers and tensor for logits
# Added loss computation to the graph
# I0918 23:19:54.064629 4654548416 feedforward_robust.py:45] Added loss computation to the graph
# Added accuracy computation to the graph
# I0918 23:19:54.071096 4654548416 feedforward_robust.py:49] Added accuracy computation to the graph
# Model graph was created
# I0918 23:19:54.073872 4654548416 feedforward_robust.py:52] Model graph was created
# Created model successfully. Now going to load weights
# I0918 23:19:54.078170 4654548416 <ipython-input-6-cc1dd069280b>:17] Created model successfully. Now going to load weights
# Model was evaluated on benign data
# I0918 23:19:54.506139 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# ----Regular test accuracy and loss ----
# I0918 23:19:54.508294 4654548416 <ipython-input-6-cc1dd069280b>:28] ----Regular test accuracy and loss ----
# (0.3424165, 0.8982)
# I0918 23:19:54.510022 4654548416 <ipython-input-6-cc1dd069280b>:29] (0.3424165, 0.8982)
# Model was evaluated on benign data
# I0918 23:19:54.530355 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# ----Regular test accuracy and loss ----
# I0918 23:19:54.531959 4654548416 <ipython-input-6-cc1dd069280b>:34] ----Regular test accuracy and loss ----
# (0.3424165, 0.8982)
# I0918 23:19:54.532986 4654548416 <ipython-input-6-cc1dd069280b>:35] (0.3424165, 0.8982)
# Model is being evaluated on FGSM data
# I0918 23:19:54.748095 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# ----FGSM test accuracy and loss ----
# I0918 23:19:54.761631 4654548416 <ipython-input-6-cc1dd069280b>:40] ----FGSM test accuracy and loss ----
# (3.3301492, 0.3424)
# I0918 23:19:54.762953 4654548416 <ipython-input-6-cc1dd069280b>:41] (3.3301492, 0.3424)

# %%
with tf.variable_scope(config['scope_name']) as scope:
    weights = reg_model.get_weights_np(sess_reg)

# %%
#With regularization
sing_vals_reg = []
for (idx, weight_matrix) in enumerate(weights):
        sig = plot_singular_values(weight_matrix, idx, "First layer penalized")
        sing_vals_reg.append(sig)

# %% [markdown]
# **Interpretation** This is pretty interesting. When you penalize the singular values of the first layer, all the other layers start increasing to compensate - I'm guessing to keep the expressiveness high. Probably, if we penalize all the singular values, it may not learn anything?
#
# So we still have not suceeded at replicating the singular value spectrum of the robust model - so it is difficult to conclude whether the singular value spectrum is a determinant of adversarial robustness or not

# %%
#With regularization - first layer
sing_vals_reg
# Out:
# [array([1.5870155e+00, 1.5522803e+00, 1.3584403e+00, 1.3370733e+00,
#         1.3070780e+00, 1.2188531e+00, 1.1234620e+00, 1.0728732e+00,
#         1.0041257e+00, 8.7067133e-01, 7.6290888e-01, 6.6413921e-01,
#         6.1234343e-01, 3.5728675e-01, 6.2625506e-04, 4.9098406e-04,
#         4.8556362e-04, 4.5167084e-04, 3.1356234e-04, 3.0216103e-04,
#         2.7841594e-04, 2.0602574e-04, 1.9646439e-04, 1.8619838e-04,
#         1.4287693e-04, 1.3560396e-04, 1.2213681e-04, 3.9542541e-05,
#         3.5572761e-05, 1.7289583e-05, 8.5304418e-06, 5.9684144e-06],
#        dtype=float32),
#  array([6.035554  , 5.8620715 , 5.20899   , 4.6957164 , 4.3550816 ,
#         4.287016  , 4.125534  , 4.0239434 , 3.7177262 , 3.1656983 ,
#         2.7954736 , 2.499863  , 2.23836   , 2.055546  , 1.7796141 ,
#         1.2052387 , 1.1660684 , 1.1480169 , 1.0525272 , 1.0315014 ,
#         0.90306103, 0.74932116, 0.6895752 , 0.6741662 , 0.5238548 ,
#         0.469349  , 0.34676093, 0.27730793, 0.22861174, 0.21915486,
#         0.12821923, 0.04902895], dtype=float32),
#  array([8.313168  , 7.097558  , 6.474968  , 6.0774064 , 5.9532666 ,
#         5.0635104 , 4.915927  , 4.690167  , 4.3526545 , 3.7610216 ,
#         3.2347915 , 3.0240717 , 2.7837446 , 2.6843023 , 2.4640486 ,
#         2.300695  , 2.2124615 , 1.9676274 , 1.8212018 , 1.6916738 ,
#         1.5309254 , 1.3916907 , 1.3467339 , 1.0976187 , 1.0488392 ,
#         0.83745235, 0.7388067 , 0.50121474, 0.40624616, 0.34694144,
#         0.24340174, 0.01908168], dtype=float32),
#  array([7.1776958 , 5.898219  , 5.498995  , 5.257844  , 4.7287526 ,
#         4.6113462 , 4.0654154 , 3.6983082 , 3.4004881 , 3.1373265 ,
#         2.8817825 , 2.74308   , 2.4891434 , 2.3049731 , 2.2443368 ,
#         2.0627778 , 1.7933652 , 1.6956596 , 1.6027057 , 1.4698237 ,
#         1.3835281 , 1.1667676 , 1.1242539 , 1.0788759 , 0.8064557 ,
#         0.7641716 , 0.6675601 , 0.30973965, 0.27230588, 0.22321582,
#         0.12589666, 0.02296172], dtype=float32),
#  array([6.5854554 , 4.5837817 , 4.286893  , 3.769714  , 3.4780478 ,
#         3.341227  , 3.0782726 , 2.9168046 , 2.873075  , 2.4816515 ,
#         2.3047612 , 2.1478589 , 2.0287678 , 1.872536  , 1.7858498 ,
#         1.5822568 , 1.5515069 , 1.4771366 , 1.3061955 , 1.2171642 ,
#         1.0994817 , 1.0202268 , 0.7808631 , 0.7147383 , 0.6232897 ,
#         0.55694413, 0.4260238 , 0.37106112, 0.28626335, 0.16256648,
#         0.07809619, 0.0314378 ], dtype=float32),
#  array([7.3493032 , 4.533474  , 4.4129305 , 3.8866436 , 3.6549172 ,
#         3.0814738 , 3.0432532 , 2.8495224 , 2.4163284 , 2.3834083 ,
#         2.0320892 , 1.816741  , 1.7238573 , 1.7074434 , 1.5123483 ,
#         1.4070817 , 1.3224729 , 1.2898788 , 1.1957868 , 1.0527304 ,
#         0.9680283 , 0.844301  , 0.7647332 , 0.68414754, 0.6275915 ,
#         0.5754952 , 0.47121438, 0.40531746, 0.26284814, 0.19970706,
#         0.11621714, 0.02375523], dtype=float32),
#  array([4.8360868 , 4.163418  , 3.348712  , 3.1064954 , 2.962943  ,
#         2.6637676 , 2.4356823 , 2.351447  , 2.0972435 , 2.0749035 ,
#         1.84771   , 1.6885501 , 1.6007267 , 1.5346999 , 1.3498926 ,
#         1.2554356 , 1.1496577 , 1.0995618 , 0.9808809 , 0.85412896,
#         0.76770544, 0.7078538 , 0.6657098 , 0.63290054, 0.53630775,
#         0.51135075, 0.4337423 , 0.25121927, 0.24018425, 0.1927696 ,
#         0.10533228, 0.06847405], dtype=float32),
#  array([11.546055 ,  5.348885 ,  3.7945395,  2.9946737,  2.530549 ,
#          1.941301 ,  1.8666426,  1.4938574,  1.1567605,  1.0363789],
#        dtype=float32)]

# %%
#Regular points
acts = reg_model.get_activation(sess_reg, x_test_flat)
diff, diff_norm = activation_distance(acts)

#Adversarial points
x_test_flat_adv = reg_model.fgsm_np(sess_reg, x_test_flat, y_test, config['eps_test'])
acts_adv = reg_model.get_activation(sess_reg, x_test_flat_adv)
diff_adv, diff_norm_adv = activation_distance(acts_adv)

# %%
diff_norm
# Out:
# [1.6056864, 1.8563683, 1.5560254, 1.3894248, 1.1853814, 1.2059872]

# %%
diff_norm_adv
# Out:
# [1.5158699, 1.7118087, 1.3908907, 1.3478867, 1.1872182, 1.2078623]

# %%
dphi_dx_robust_first_reg = reg_model.get_dphi_dx(sess_reg, x_test_flat)
np.mean(np.abs(dphi_dx_robust_first_reg))
# Out:
# 0.29407898

# %%
dpred_dx_robust_first_reg = reg_model.get_pred_dx(sess_reg, x_test_flat)
np.mean(np.abs(dpred_dx_robust_first_reg))
# Out:
# 0.53012115

# %% [markdown]
# # Trace regularization for all layers

# %%
#Config
config['eps_train'] = 0.1
config['eps_test'] = 0.1
config['tensorboard_dir'] = "tb/"
config['weights_dir'] = "weights/"
config['load_counter'] = 126
config['sigma'] = tf.nn.relu
config['scope_name'] = "model_non_robust"

# %%
model_all_reg, sess_all_reg = regular_training(config)
# Out:
# Initialized instance variables of the robust model class
# I0918 23:19:56.447826 4654548416 feedforward_robust.py:30] Initialized instance variables of the robust model class
# Created placeholders for x and y
# I0918 23:19:56.450947 4654548416 feedforward_robust.py:36] Created placeholders for x and y
# Created layers and tensor for logits
# I0918 23:19:56.487494 4654548416 feedforward_robust.py:40] Created layers and tensor for logits
# Added loss computation to the graph
# I0918 23:19:56.506758 4654548416 feedforward_robust.py:45] Added loss computation to the graph
# Added accuracy computation to the graph
# I0918 23:19:56.513241 4654548416 feedforward_robust.py:49] Added accuracy computation to the graph
# Model graph was created
# I0918 23:19:56.515966 4654548416 feedforward_robust.py:52] Model graph was created
# Created model successfully. Now going to load weights
# I0918 23:19:56.520689 4654548416 <ipython-input-6-cc1dd069280b>:17] Created model successfully. Now going to load weights
# Model was evaluated on benign data
# I0918 23:19:56.877187 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# ----Regular test accuracy and loss ----
# I0918 23:19:56.878599 4654548416 <ipython-input-6-cc1dd069280b>:28] ----Regular test accuracy and loss ----
# (0.4752624, 0.8653)
# I0918 23:19:56.880122 4654548416 <ipython-input-6-cc1dd069280b>:29] (0.4752624, 0.8653)
# Model was evaluated on benign data
# I0918 23:19:56.902688 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# ----Regular test accuracy and loss ----
# I0918 23:19:56.904001 4654548416 <ipython-input-6-cc1dd069280b>:34] ----Regular test accuracy and loss ----
# (0.4752624, 0.8653)
# I0918 23:19:56.905097 4654548416 <ipython-input-6-cc1dd069280b>:35] (0.4752624, 0.8653)
# Model is being evaluated on FGSM data
# I0918 23:19:57.138197 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# ----FGSM test accuracy and loss ----
# I0918 23:19:57.153321 4654548416 <ipython-input-6-cc1dd069280b>:40] ----FGSM test accuracy and loss ----
# (3.4028633, 0.1185)
# I0918 23:19:57.154651 4654548416 <ipython-input-6-cc1dd069280b>:41] (3.4028633, 0.1185)

# %%
with tf.variable_scope(config['scope_name']) as scope:
    weights = model_all_reg.get_weights_np(sess_all_reg)

# %%
#With regularization
sing_vals_all = []
for (idx, weight_matrix) in enumerate(weights):
        sig = plot_singular_values(weight_matrix, idx, "all layers penalized")
        sing_vals_all.append(sig)

# %%
#Regular points
acts = model_all_reg.get_activation(sess_all_reg, x_test_flat)
diff, diff_norm = activation_distance(acts)

#Adversarial points
x_test_flat_adv = model_all_reg.fgsm_np(sess_all_reg, x_test_flat, y_test, config['eps_test'])
acts_adv = model_all_reg.get_activation(sess_all_reg, x_test_flat_adv)
diff_adv, diff_norm_adv = activation_distance(acts_adv)

# %%
diff_norm
# Out:
# [1.2381881, 1.1723968, 0.9998556, 1.2088721, 1.156904, 1.2247998]

# %%
diff_norm_adv
# Out:
# [1.2208154, 1.1831144, 1.000097, 1.2062595, 1.1468935, 1.2146919]

# %%
dphi_dx_robust_all_reg = reg_model.get_dphi_dx(sess_all_reg, x_test_flat)
np.mean(np.abs(dphi_dx_robust_all_reg))
# Out:
# 0.20034555

# %%
dpred_dx_robust_all_reg = reg_model.get_pred_dx(sess_all_reg, x_test_flat)
np.mean(np.abs(dpred_dx_robust_all_reg))
# Out:
# 0.0020152025

# %% [markdown]
# # FGSM Adversarial Training

# %%
#Config
config['eps_train'] = 0.1
config['eps_test'] = 0.1
config['tensorboard_dir'] = "tb/"
config['weights_dir'] = "weights/"
config['load_counter'] = 280
config['sigma'] = tf.nn.relu
config['scope_name'] = "model_robust"

# %%
model_rob, sess_rob = adversarial_training(config)
# Out:
# Adversarial Training
# I0918 23:19:59.100296 4654548416 <ipython-input-8-d7d1c01af8cd>:18] Adversarial Training
# Initialized instance variables of the robust model class
# I0918 23:19:59.101765 4654548416 feedforward_robust.py:30] Initialized instance variables of the robust model class
# Created placeholders for x and y
# I0918 23:19:59.105122 4654548416 feedforward_robust.py:36] Created placeholders for x and y
# Created layers and tensor for logits
# I0918 23:19:59.206065 4654548416 feedforward_robust.py:40] Created layers and tensor for logits
# Added loss computation to the graph
# I0918 23:19:59.225757 4654548416 feedforward_robust.py:45] Added loss computation to the graph
# Added accuracy computation to the graph
# I0918 23:19:59.231918 4654548416 feedforward_robust.py:49] Added accuracy computation to the graph
# Model graph was created
# I0918 23:19:59.234352 4654548416 feedforward_robust.py:52] Model graph was created
# Epoch: 0001    cost: 1.728547424
# I0918 23:20:04.864713 4654548416 feedforward_robust.py:414] Epoch: 0001    cost: 1.728547424
# Accuracy on batch: 0.562500
# I0918 23:20:04.866333 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.562500
# Epoch: 0002    cost: 1.183575003
# I0918 23:20:08.932054 4654548416 feedforward_robust.py:414] Epoch: 0002    cost: 1.183575003
# Accuracy on batch: 0.593750
# I0918 23:20:08.934082 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.593750
# Epoch: 0003    cost: 0.976459977
# I0918 23:20:12.247305 4654548416 feedforward_robust.py:414] Epoch: 0003    cost: 0.976459977
# Accuracy on batch: 0.687500
# I0918 23:20:12.248716 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.687500
# Epoch: 0004    cost: 0.840341307
# I0918 23:20:15.937330 4654548416 feedforward_robust.py:414] Epoch: 0004    cost: 0.840341307
# Accuracy on batch: 0.718750
# I0918 23:20:15.938514 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.718750
# Epoch: 0005    cost: 0.750941221
# I0918 23:20:19.574774 4654548416 feedforward_robust.py:414] Epoch: 0005    cost: 0.750941221
# Accuracy on batch: 0.687500
# I0918 23:20:19.575866 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.687500
# Epoch: 0006    cost: 0.690480099
# I0918 23:20:22.852874 4654548416 feedforward_robust.py:414] Epoch: 0006    cost: 0.690480099
# Accuracy on batch: 0.750000
# I0918 23:20:22.853974 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.750000
# Epoch: 0007    cost: 0.655512446
# I0918 23:20:26.288035 4654548416 feedforward_robust.py:414] Epoch: 0007    cost: 0.655512446
# Accuracy on batch: 0.718750
# I0918 23:20:26.289252 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.718750
# Epoch: 0008    cost: 0.636567083
# I0918 23:20:30.132345 4654548416 feedforward_robust.py:414] Epoch: 0008    cost: 0.636567083
# Accuracy on batch: 0.812500
# I0918 23:20:30.133522 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.812500
# Epoch: 0009    cost: 0.614854669
# I0918 23:20:34.467642 4654548416 feedforward_robust.py:414] Epoch: 0009    cost: 0.614854669
# Accuracy on batch: 0.750000
# I0918 23:20:34.469398 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.750000
# Epoch: 0010    cost: 0.603093558
# I0918 23:20:38.056339 4654548416 feedforward_robust.py:414] Epoch: 0010    cost: 0.603093558
# Accuracy on batch: 0.843750
# I0918 23:20:38.057550 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.843750
# Epoch: 0011    cost: 0.584793105
# I0918 23:20:42.297402 4654548416 feedforward_robust.py:414] Epoch: 0011    cost: 0.584793105
# Accuracy on batch: 0.781250
# I0918 23:20:42.298627 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.781250
# Epoch: 0012    cost: 0.569421601
# I0918 23:20:45.987252 4654548416 feedforward_robust.py:414] Epoch: 0012    cost: 0.569421601
# Accuracy on batch: 0.906250
# I0918 23:20:45.988797 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.906250
# Epoch: 0013    cost: 0.562848336
# I0918 23:20:49.358741 4654548416 feedforward_robust.py:414] Epoch: 0013    cost: 0.562848336
# Accuracy on batch: 0.937500
# I0918 23:20:49.360150 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.937500
# Epoch: 0014    cost: 0.546807716
# I0918 23:20:52.702815 4654548416 feedforward_robust.py:414] Epoch: 0014    cost: 0.546807716
# Accuracy on batch: 0.843750
# I0918 23:20:52.703967 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.843750
# Epoch: 0015    cost: 0.540940787
# I0918 23:20:56.036289 4654548416 feedforward_robust.py:414] Epoch: 0015    cost: 0.540940787
# Accuracy on batch: 0.875000
# I0918 23:20:56.037461 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.875000
# Epoch: 0016    cost: 0.533218652
# I0918 23:20:59.491418 4654548416 feedforward_robust.py:414] Epoch: 0016    cost: 0.533218652
# Accuracy on batch: 0.937500
# I0918 23:20:59.493098 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.937500
# Epoch: 0017    cost: 0.531020520
# I0918 23:21:03.283004 4654548416 feedforward_robust.py:414] Epoch: 0017    cost: 0.531020520
# Accuracy on batch: 0.812500
# I0918 23:21:03.284384 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.812500
# Epoch: 0018    cost: 0.520467634
# I0918 23:21:07.211988 4654548416 feedforward_robust.py:414] Epoch: 0018    cost: 0.520467634
# Accuracy on batch: 0.843750
# I0918 23:21:07.213084 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.843750
# Epoch: 0019    cost: 0.516405392
# I0918 23:21:10.891791 4654548416 feedforward_robust.py:414] Epoch: 0019    cost: 0.516405392
# Accuracy on batch: 0.843750
# I0918 23:21:10.893061 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.843750
# Epoch: 0020    cost: 0.506224569
# I0918 23:21:14.850499 4654548416 feedforward_robust.py:414] Epoch: 0020    cost: 0.506224569
# Accuracy on batch: 0.906250
# I0918 23:21:14.851844 4654548416 feedforward_robust.py:415] Accuracy on batch: 0.906250
# Optimization Finished!
# I0918 23:21:14.854128 4654548416 feedforward_robust.py:416] Optimization Finished!
# Final Train Loss 0.486979
# I0918 23:21:15.382426 4654548416 feedforward_robust.py:424] Final Train Loss 0.486979
# Final Train Accuracy 0.815800:
# I0918 23:21:15.384232 4654548416 feedforward_robust.py:425] Final Train Accuracy 0.815800:
# Final Train Loss on Adv points 0.519547
# I0918 23:21:16.566140 4654548416 feedforward_robust.py:470] Final Train Loss on Adv points 0.519547
# Final Train Accuracy on Adv points 0.836700
# I0918 23:21:16.567238 4654548416 feedforward_robust.py:471] Final Train Accuracy on Adv points 0.836700
# Model was trained on adversarial data
# I0918 23:21:16.568580 4654548416 feedforward_robust.py:472] Model was trained on adversarial data
# Model was evaluated on benign data
# I0918 23:21:16.624268 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# (0.48078278, 0.817)
# Model is being evaluated on FGSM data
# I0918 23:21:16.998486 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# (0.5319765, 0.8319)

# %%
with tf.variable_scope(config['scope_name']) as scope:
    weights_robust = model_rob.get_weights_np(sess_rob)

# %%
sing_vals_robust = []
for (idx, weight_matrix) in enumerate(weights_robust):
    sig = plot_singular_values(weight_matrix, idx, "FGSM adversarially trained model")
    sing_vals_robust.append(sig)

# %%
dphi_dx_robust = model_rob.get_dphi_dx(sess_rob, x_test_flat)
np.mean(np.abs(dphi_dx_robust))
# Out:
# 0.34009773

# %%
dpred_dx_robust = model_rob.get_pred_dx(sess_rob, x_test_flat)
np.mean(np.abs(dpred_dx_robust))
# Out:
# 0.13320506

# %%
sing_vals[0]
# Out:
# array([11.189289 , 10.133197 ,  9.383851 ,  8.92445  ,  8.247922 ,
#         7.969636 ,  7.4290295,  7.0685034,  6.6811824,  6.1500745,
#         5.970582 ,  5.6832013,  5.439685 ,  5.1961956,  5.0047846,
#         4.7424994,  4.5128593,  4.3439555,  4.1835628,  3.9895031,
#         3.7153032,  3.6492496,  3.417802 ,  3.3370526,  3.3204548,
#         3.294197 ,  3.0694237,  2.9688969,  2.8788092,  2.7434793,
#         2.6681807,  1.4231784], dtype=float32)

# %%
sing_vals_robust[0]
# Out:
# array([8.869713  , 2.9238036 , 2.830964  , 2.5285273 , 2.468152  ,
#        2.3325036 , 2.2371426 , 2.150985  , 2.0537913 , 1.9551693 ,
#        1.9089277 , 1.8121405 , 1.7345315 , 1.59177   , 1.5633192 ,
#        1.5223619 , 1.4888304 , 1.4781235 , 1.4189152 , 1.2356037 ,
#        1.2200543 , 1.1614155 , 1.1261286 , 1.0636147 , 1.0370299 ,
#        0.99238235, 0.8886876 , 0.8753338 , 0.8661556 , 0.64526683,
#        0.5877553 , 0.5258607 ], dtype=float32)

# %%
sing_vals[1]
# Out:
# array([3.674316  , 3.3551764 , 3.224709  , 2.9054708 , 2.6243584 ,
#        2.4510684 , 2.1869967 , 2.1103704 , 1.7720344 , 1.5988731 ,
#        1.4801615 , 1.421275  , 1.3496728 , 1.2716495 , 1.1624023 ,
#        1.0521415 , 1.0061094 , 0.94067425, 0.904368  , 0.82833225,
#        0.75014293, 0.6533072 , 0.61833286, 0.5395455 , 0.42479357,
#        0.39901435, 0.33884445, 0.26813343, 0.20976494, 0.18486662,
#        0.15978248, 0.03111679], dtype=float32)

# %%
sing_vals_robust[1]
# Out:
# array([2.174216  , 2.067168  , 1.9713092 , 1.8547459 , 1.7365333 ,
#        1.6105733 , 1.5813849 , 1.4438851 , 1.4119642 , 1.3467199 ,
#        1.3149594 , 1.1944592 , 1.1632769 , 1.0831065 , 1.0359458 ,
#        0.9345094 , 0.9099571 , 0.82428193, 0.8037578 , 0.7150761 ,
#        0.69795495, 0.6429879 , 0.5957946 , 0.5606439 , 0.4804351 ,
#        0.41107425, 0.3681796 , 0.26139098, 0.22299433, 0.17947853,
#        0.13135445, 0.03744645], dtype=float32)

# %%
sing_vals[2]
# Out:
# array([3.3668115 , 2.842233  , 2.7448304 , 2.5716846 , 2.5023568 ,
#        2.3724024 , 2.2186227 , 2.019235  , 1.795118  , 1.5796243 ,
#        1.4817913 , 1.4066254 , 1.3463677 , 1.25288   , 1.2033571 ,
#        1.0469009 , 1.0039477 , 0.91686976, 0.8075825 , 0.76937425,
#        0.758841  , 0.63528323, 0.55939764, 0.49177903, 0.47970247,
#        0.3502487 , 0.29832286, 0.24977762, 0.20475344, 0.14861573,
#        0.07453168, 0.01873747], dtype=float32)

# %%
sing_vals_robust[2]
# Out:
# array([2.1562545e+00, 1.9519883e+00, 1.8735348e+00, 1.8088096e+00,
#        1.7497213e+00, 1.6440113e+00, 1.5709667e+00, 1.5377996e+00,
#        1.4906993e+00, 1.3829646e+00, 1.3385144e+00, 1.2905406e+00,
#        1.1959442e+00, 1.1631064e+00, 1.0850821e+00, 1.0126938e+00,
#        9.6758896e-01, 9.3437320e-01, 8.2011765e-01, 7.8795391e-01,
#        7.0974606e-01, 6.2456799e-01, 5.5160844e-01, 4.9717969e-01,
#        4.7578073e-01, 3.8793287e-01, 3.4336451e-01, 2.2906452e-01,
#        1.8209611e-01, 1.3809787e-01, 7.6764509e-02, 2.7035736e-04],
#       dtype=float32)

# %%
sing_vals[-1]
# Out:
# array([2.3056653 , 2.0326595 , 1.8763782 , 1.7655128 , 1.5709738 ,
#        1.3455315 , 1.2124654 , 0.9837641 , 0.81992024, 0.6042539 ],
#       dtype=float32)

# %%
sing_vals_robust[-1]
# Out:
# array([2.037198  , 1.9406292 , 1.9140413 , 1.7797343 , 1.6288444 ,
#        1.3781286 , 1.2663594 , 1.1950443 , 0.97452134, 0.9116946 ],
#       dtype=float32)

# %%
#Regular points
acts = model_rob.get_activation(sess_rob, x_test_flat)
diff, diff_norm = activation_distance(acts)

#Adversarial points
x_test_flat_adv = model_rob.fgsm_np(sess_rob, x_test_flat, y_test, config['eps_test'])
acts_adv = model_rob.get_activation(sess_rob, x_test_flat_adv)
diff_adv, diff_norm_adv = activation_distance(acts_adv)

# %%
diff_norm
# Out:
# [1.0991806, 1.1117404, 1.0143824, 1.0664507, 1.0503776, 1.1385813]

# %%
diff_norm_adv
# Out:
# [1.1091744, 1.055647, 0.9818316, 1.044788, 1.0607667, 1.0954963]

# %% [markdown]
# # Comparison plots

# %% [markdown]
# ## Distances

# %%
model_list = [model_non_robust, model_all_reg, model_rob, model_hybrid, reg_model]
sess_list = [sess_non_robust, sess_all_reg, sess_rob, sess_hybrid, sess_reg]
scope_list = ["model_non_robust", "model_non_robust", "model_robust", "hybrid", "model_non_robust"]
legend_list = ['non robust', 'all layers trace reg', 'robust', 'hybrid', 'first layer trace reg']

# %%
make_dist_plot_all_models(model_list, sess_list, scope_list, legend_list, order = 2)
# Out:
# Getting activation distances between regular and FGSM data
# I0918 23:21:19.333104 4654548416 feedforward_robust.py:309] Getting activation distances between regular and FGSM data
# Found correct and incorrect indices
# I0918 23:21:19.907583 4654548416 feedforward_robust.py:314] Found correct and incorrect indices
# Found average and standard deviation of distances
# I0918 23:21:30.132757 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:21:30.696346 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:21:39.505553 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Getting activation distances between regular and FGSM data
# I0918 23:21:39.548207 4654548416 feedforward_robust.py:309] Getting activation distances between regular and FGSM data
# Found correct and incorrect indices
# I0918 23:21:40.001995 4654548416 feedforward_robust.py:314] Found correct and incorrect indices
# Found average and standard deviation of distances
# I0918 23:21:49.557151 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:21:50.676796 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:21:58.897446 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Getting activation distances between regular and FGSM data
# I0918 23:21:58.927674 4654548416 feedforward_robust.py:309] Getting activation distances between regular and FGSM data
# Found correct and incorrect indices
# I0918 23:21:59.332334 4654548416 feedforward_robust.py:314] Found correct and incorrect indices
# Found average and standard deviation of distances
# I0918 23:22:08.357071 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:22:15.805745 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:22:17.342200 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Getting activation distances between regular and FGSM data
# I0918 23:22:17.353726 4654548416 feedforward_robust.py:309] Getting activation distances between regular and FGSM data
# Found correct and incorrect indices
# I0918 23:22:17.735584 4654548416 feedforward_robust.py:314] Found correct and incorrect indices
# Found average and standard deviation of distances
# I0918 23:22:26.731994 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:22:29.987776 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:22:35.769315 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Getting activation distances between regular and FGSM data
# I0918 23:22:35.792449 4654548416 feedforward_robust.py:309] Getting activation distances between regular and FGSM data
# Found correct and incorrect indices
# I0918 23:22:36.204500 4654548416 feedforward_robust.py:314] Found correct and incorrect indices
# Found average and standard deviation of distances
# I0918 23:22:45.083273 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:22:48.161154 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:22:54.055819 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# True

# %%
make_dist_plot_all_models(model_list, sess_list, scope_list, legend_list, order = float("inf"))
# Out:
# Getting activation distances between regular and FGSM data
# I0918 23:22:54.306233 4654548416 feedforward_robust.py:309] Getting activation distances between regular and FGSM data
# Found correct and incorrect indices
# I0918 23:22:54.644698 4654548416 feedforward_robust.py:314] Found correct and incorrect indices
# Found average and standard deviation of distances
# I0918 23:23:03.746474 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:23:04.293992 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:23:12.842514 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Getting activation distances between regular and FGSM data
# I0918 23:23:12.879946 4654548416 feedforward_robust.py:309] Getting activation distances between regular and FGSM data
# Found correct and incorrect indices
# I0918 23:23:13.208179 4654548416 feedforward_robust.py:314] Found correct and incorrect indices
# Found average and standard deviation of distances
# I0918 23:23:22.310472 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:23:23.406450 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:23:32.199767 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Getting activation distances between regular and FGSM data
# I0918 23:23:32.240097 4654548416 feedforward_robust.py:309] Getting activation distances between regular and FGSM data
# Found correct and incorrect indices
# I0918 23:23:32.634853 4654548416 feedforward_robust.py:314] Found correct and incorrect indices
# Found average and standard deviation of distances
# I0918 23:23:42.420709 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:23:49.919090 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:23:51.466512 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Getting activation distances between regular and FGSM data
# I0918 23:23:51.481076 4654548416 feedforward_robust.py:309] Getting activation distances between regular and FGSM data
# Found correct and incorrect indices
# I0918 23:23:51.919932 4654548416 feedforward_robust.py:314] Found correct and incorrect indices
# Found average and standard deviation of distances
# I0918 23:24:01.395727 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:24:04.867900 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:24:10.661333 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Getting activation distances between regular and FGSM data
# I0918 23:24:10.687211 4654548416 feedforward_robust.py:309] Getting activation distances between regular and FGSM data
# Found correct and incorrect indices
# I0918 23:24:11.038492 4654548416 feedforward_robust.py:314] Found correct and incorrect indices
# Found average and standard deviation of distances
# I0918 23:24:20.190639 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:24:23.320148 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# Found average and standard deviation of distances
# I0918 23:24:29.304797 4654548416 feedforward_robust.py:329] Found average and standard deviation of distances
# True

# %% [markdown]
# ## Stats

# %%
model_list = [model_non_robust, model_all_reg, model_rob, model_hybrid, reg_model]
sess_list = [sess_non_robust, sess_all_reg, sess_rob, sess_hybrid, sess_reg]
scope_list = ["model_non_robust", "model_non_robust", "model_robust", "hybrid", "model_non_robust"]

# %%
reg_evals, adv_evals, margins, dphi_dxs = get_stats_all_models(model_list, sess_list, scope_list)
# Out:
# Model was evaluated on benign data
# I0918 23:24:29.892670 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model is being evaluated on FGSM data
# I0918 23:24:30.209707 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Obtained featurizations
# I0918 23:24:30.241141 4654548416 feedforward_robust.py:216] Obtained featurizations
# Created feat adv graph
# I0918 23:24:30.400527 4654548416 feedforward_robust.py:224] Created feat adv graph
# iteration: 0
# loss 0.257391
# iteration: 1
# loss 0.334171
# iteration: 2
# loss 0.425993
# iteration: 3
# loss 0.533689
# iteration: 4
# loss 0.657184
# iteration: 5
# loss 0.795203
# iteration: 6
# loss 0.946203
# iteration: 7
# loss 1.107344
# iteration: 8
# loss 1.275187
# iteration: 9
# loss 1.446030
# iteration: 10
# loss 1.616064
# iteration: 11
# loss 1.781188
# iteration: 12
# loss 1.937252
# iteration: 13
# loss 2.080615
# iteration: 14
# loss 2.208084
# iteration: 15
# loss 2.316975
# iteration: 16
# loss 2.404972
# iteration: 17
# loss 2.470462
# iteration: 18
# loss 2.512582
# iteration: 19
# loss 2.530714
# iteration: 20
# loss 2.536422
# iteration: 21
# loss 2.541760
# iteration: 22
# loss 2.546731
# iteration: 23
# loss 2.551281
# iteration: 24
# loss 2.555517
# iteration: 25
# loss 2.559445
# iteration: 26
# loss 2.563066
# iteration: 27
# loss 2.566374
# iteration: 28
# loss 2.569420
# iteration: 29
# loss 2.572196
# iteration: 30
# loss 2.574708
# iteration: 31
# loss 2.576969
# iteration: 32
# loss 2.579028
# iteration: 33
# loss 2.580822
# iteration: 34
# loss 2.582429
# iteration: 35
# loss 2.583852
# iteration: 36
# loss 2.585129
# iteration: 37
# loss 2.586267
# iteration: 38
# loss 2.587256
# iteration: 39
# loss 2.588129
# iteration: 40
# loss 2.588952
# iteration: 41
# loss 2.589713
# iteration: 42
# loss 2.590412
# iteration: 43
# loss 2.591060
# iteration: 44
# loss 2.591683
# iteration: 45
# loss 2.592263
# iteration: 46
# loss 2.592800
# iteration: 47
# loss 2.593296
# iteration: 48
# loss 2.593746
# iteration: 49
# loss 2.594152
# iteration: 50
# loss 2.594520
# loss 6.753028
# iteration: 164
# loss 6.753028
# iteration: 165
# loss 6.753028
# iteration: 166
# loss 6.753028
# iteration: 167
# loss 6.753028
# iteration: 168
# loss 6.753028
# iteration: 169
# loss 6.753028
# iteration: 170
# loss 6.753028
# iteration: 171
# loss 6.753028
# iteration: 172
# loss 6.753028
# iteration: 173
# Found adversarial featurizations
# I0918 23:24:36.485329 4654548416 feedforward_robust.py:219] Found adversarial featurizations
# loss 6.753028
# iteration: 174
# loss 6.753028
# iteration: 175
# loss 6.753028
# iteration: 176
# loss 6.753028
# iteration: 177
# loss 6.753028
# iteration: 178
# loss 6.753028
# iteration: 179
# loss 6.753028
# iteration: 180
# loss 6.753028
# iteration: 181
# loss 6.753028
# iteration: 182
# loss 6.753028
# iteration: 183
# loss 6.753028
# iteration: 184
# loss 6.753028
# iteration: 185
# loss 6.753028
# iteration: 186
# loss 6.753028
# iteration: 187
# loss 6.753028
# iteration: 188
# loss 6.753028
# iteration: 189
# loss 6.753028
# iteration: 190
# loss 6.753028
# iteration: 191
# loss 6.753028
# iteration: 192
# loss 6.753028
# iteration: 193
# loss 6.753028
# iteration: 194
# loss 6.753028
# iteration: 195
# loss 6.753028
# iteration: 196
# loss 6.753028
# iteration: 197
# loss 6.753028
# iteration: 198
# loss 6.753028
# iteration: 199
# loss 6.753028
# Model was evaluated from featurizations
# I0918 23:24:36.528144 4654548416 feedforward_robust.py:383] Model was evaluated from featurizations
# Model was evaluated on benign data
# I0918 23:24:36.853286 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model is being evaluated on FGSM data
# I0918 23:24:37.189951 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Obtained featurizations
# I0918 23:24:37.319371 4654548416 feedforward_robust.py:216] Obtained featurizations
# Created feat adv graph
# I0918 23:24:37.606405 4654548416 feedforward_robust.py:224] Created feat adv graph
# iteration: 0
# loss 1.355276
# iteration: 1
# loss 1.949408
# iteration: 2
# loss 2.644230
# iteration: 3
# loss 3.408081
# iteration: 4
# loss 4.208314
# iteration: 5
# loss 5.014053
# iteration: 6
# loss 5.802104
# iteration: 7
# loss 6.555888
# iteration: 8
# loss 7.263124
# iteration: 9
# loss 7.917651
# iteration: 10
# loss 8.515601
# iteration: 11
# loss 9.054531
# iteration: 12
# loss 9.532631
# iteration: 13
# loss 9.948860
# iteration: 14
# loss 10.302873
# iteration: 15
# loss 10.595261
# iteration: 16
# loss 10.825107
# iteration: 17
# loss 10.994023
# iteration: 18
# loss 11.104135
# iteration: 19
# loss 11.155946
# iteration: 20
# loss 11.178612
# iteration: 21
# loss 11.199924
# iteration: 22
# loss 11.219781
# iteration: 23
# loss 11.238390
# iteration: 24
# loss 11.255631
# iteration: 25
# loss 11.271585
# iteration: 26
# loss 11.286327
# iteration: 27
# loss 11.299988
# iteration: 28
# loss 11.312480
# iteration: 29
# loss 11.323856
# iteration: 30
# loss 11.334126
# iteration: 31
# loss 11.343389
# iteration: 32
# loss 11.351714
# iteration: 33
# loss 11.359300
# iteration: 34
# loss 11.366111
# iteration: 35
# loss 11.372290
# iteration: 36
# loss 11.377769
# loss 11.829391
# iteration: 185
# loss 11.829391
# iteration: 186
# loss 11.829391
# iteration: 187
# loss 11.829391
# iteration: 188
# loss 11.829391
# iteration: 189
# loss 11.829391
# iteration: 190
# loss 11.829391
# iteration: 191
# loss 11.829391
# iteration: 192
# loss 11.829391
# iteration: 193
# loss 11.829391
# iteration: 194
# loss 11.829391
# iteration: 195
# loss 11.829391
# iteration: 196
# loss 11.829391
# iteration: 197
# loss 11.829391
# iteration: 198
# loss 11.829391
# iteration: 199
# loss 11.829391
# Found adversarial featurizations
# I0918 23:24:41.402127 4654548416 feedforward_robust.py:219] Found adversarial featurizations
# Model was evaluated from featurizations
# I0918 23:24:41.447530 4654548416 feedforward_robust.py:383] Model was evaluated from featurizations

# %%
#model_non_robust, model_all_reg, model_rob, model_hybrid, reg_model

# %%
reg_evals
# Out:
# [(0.17380294, 0.9559),
#  (0.4752624, 0.8653),
#  (0.48078278, 0.817),
#  (0.6153447, 0.8071),
#  (0.3424165, 0.8982)]

# %%
adv_evals
# Out:
# [(6.6653485, 0.0579),
#  (3.4028633, 0.1185),
#  (0.5319765, 0.8319),
#  (2.5958252, 0.362),
#  (3.3301492, 0.3424)]

# %%
dphi_dxs
# Out:
# [0.8664375, 0.20034555, 0.34009773, 0.39415258, 0.29407898]

# %%
margins
# Out:
# [0.3264, 0.2837, 0.0019, 0.0027, 0.0225]

# %%
labels = ['non robust', 'Sing val all', 'fgsm train', 'hybrid', 'sing val first']

# %%
adv_evals_np = np.array(adv_evals)
acc_adv = adv_evals_np[:, 1]

# %%
x = 2*np.arange(len(labels))  # the label locations
width = 0.60  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, dphi_dxs, width, label='dphi_dx')
rects2 = ax.bar(x + width/2, margins, width, label='margin')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Margins/ Gradient means')
ax.set_title('Margins and gradient for diferent models')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.show()
print(adv_evals_np[:, 1])
# Out:
# [0.0579 0.1185 0.8319 0.362  0.3424]

# %%
x = 2*np.arange(len(labels))  # the label locations
width = 0.60  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, dphi_dxs, width, label='dphi_dx')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Gradient means')
ax.set_ylim((0, 1.1))
ax.set_title('Margins and gradient for diferent models')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


color = 'tab:orange'
ax2 = ax.twinx()
rects2 = ax2.bar(x + width/2, margins, width, label='margin', color = color)
ax2.set_ylabel('Margins')
ax2.set_ylim((0, 0.40))
#ax.set_xticks(x)
#ax.set_xticklabels(labels)
#ax2.legend(legend_loc = (1.0, 0.8))


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for (idx, rect) in enumerate(rects1):
        height = rect.get_height()
        height_2 = rects2[idx].get_height() * (1.0/0.37)
        height = max(height, height_2)
        ax.annotate('{:0.3f}'.format(acc_adv[idx]),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

plt.show()
print(adv_evals_np[:, 1])
# Out:
# [0.0579 0.1185 0.8319 0.362  0.3424]

# %% [markdown]
# ## Accuracies

# %%
model_list = [model_non_robust, model_all_reg, model_rob, model_hybrid, reg_model]
sess_list = [sess_non_robust, sess_all_reg, sess_rob, sess_hybrid, sess_reg]
eps_list = [0, 0.02, 0.05, 0.1, 0.2, 0.3]
scope_list = ["model_non_robust", "model_non_robust", "model_robust", "hybrid", "model_non_robust"]
legend_list = ['non_robust', 'all layers trace reg', 'robust', 'hybrid', 'first layer trace reg']

# %%
make_plot_acc_vs_eps(model_list, sess_list, eps_list, legend_list, scope_list, pgd = False)
# Out:
# Model is being evaluated on FGSM data
# I0918 23:25:25.152992 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:25.559371 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:25.972880 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:26.388430 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:26.799853 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:27.214611 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:27.656911 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:28.086344 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:28.546397 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:29.053392 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:29.506997 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:29.966335 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:30.421765 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:30.878912 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:31.339443 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:31.786471 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:32.249080 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:32.792557 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:33.284880 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:33.754667 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:34.252036 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:34.813152 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:35.299613 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:35.772901 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:36.252435 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:36.870687 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:37.351506 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:37.826247 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:38.306568 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# Model is being evaluated on FGSM data
# I0918 23:25:38.795326 4654548416 feedforward_robust.py:363] Model is being evaluated on FGSM data
# True

# %%
model_list = [model_non_robust, model_all_reg, model_rob, model_hybrid, reg_model]
sess_list = [sess_non_robust, sess_all_reg, sess_rob, sess_hybrid, sess_reg]
eps_list = [0, 0.02, 0.05, 0.1, 0.2, 0.3]
scope_list = ["model_non_robust", "model_non_robust", "model_robust", "hybrid", "model_non_robust"]
legend_list = ['non_robust', 'all layers trace reg', 'robust', 'hybrid', 'first layer trace reg']

# %%
make_plot_acc_vs_eps(model_list, sess_list, eps_list, legend_list, scope_list, pgd = True)

# %% [markdown]
# ## Black box accuracies

# %%
model_list = [model_non_robust, model_all_reg, model_rob, model_hybrid, reg_model]
sess_list = [sess_non_robust, sess_all_reg, sess_rob, sess_hybrid, sess_reg]
eps_list = [0, 0.02, 0.05, 0.1, 0.2, 0.3]
angle_list = [10, 30, 40, 50, 60, 70]
scope_list = ["model_non_robust", "model_non_robust", "model_robust", "hybrid", "model_non_robust"]
legend_list = ['non_robust', 'all layers trace reg', 'robust', 'hybrid', 'first layer trace reg']

# %%
make_plot_acc_vs_eps_black_box(model_list, sess_list, eps_list, angle_list, legend_list, scope_list)
# Out:
# Model was evaluated on benign data
# I0918 23:37:00.083452 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:00.106393 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:00.132121 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:00.162782 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:03.525106 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:03.557832 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:03.590770 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:03.626340 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:06.471728 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:06.498318 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:06.523030 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:06.546406 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:10.088464 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:10.122157 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:10.149632 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:10.176994 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:14.981127 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:15.012209 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:15.035459 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:15.058031 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:18.171504 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:18.204318 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:18.240233 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:18.273428 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:19.300133 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:19.326128 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:19.352739 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:19.375749 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:22.511415 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:22.535233 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:22.557627 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:22.579971 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:26.204739 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:26.229488 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:26.254885 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:26.279812 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:29.326001 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:29.351496 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:29.376543 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:29.400974 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:32.804636 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:32.832844 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:32.853859 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:32.882736 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:36.073288 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:36.094954 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:36.128152 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:36.155040 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:37.140973 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:37.174450 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:37.199892 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:37.224954 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:39.998656 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:40.020604 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:40.041960 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:40.069598 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:42.931437 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:42.955698 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:42.983036 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:43.010334 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:45.857836 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:45.886962 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:45.908083 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:45.935596 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:49.246614 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:49.290349 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:49.332391 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:49.368971 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:54.591202 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:54.615138 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:54.636952 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:54.659111 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:55.740940 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:55.763807 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:55.802794 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:55.839473 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:58.675451 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:58.697441 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:58.718625 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:37:58.738682 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:01.219642 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:01.240709 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:01.261600 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:01.282454 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:03.490148 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:03.510715 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:03.532663 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:03.554492 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:06.032032 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:06.053913 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:06.075269 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:06.097252 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:08.966478 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:08.991667 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:09.014430 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:09.046279 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:10.266047 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:10.297101 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:10.319642 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:10.341907 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:13.385109 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:13.417913 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:13.465128 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:13.494053 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:16.176613 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:16.198318 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:16.218970 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:16.241285 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:18.448981 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:18.469744 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:18.490513 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:18.512494 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:20.956137 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:20.977407 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:20.997458 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:21.018373 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:23.422577 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:23.442975 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:23.470797 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# Model was evaluated on benign data
# I0918 23:38:23.491921 4654548416 feedforward_robust.py:356] Model was evaluated on benign data
# True

# %% [markdown]
# ## Singular Values

# %%
norm_factor_non = sing_vals[0][0]
sing_non = sing_vals[0]/norm_factor_non
norm_factor_rob = sing_vals_robust[0][0]
sing_rob = sing_vals_robust[0]/norm_factor_rob

plt.loglog(range(len(sing_vals[0])), sing_non , label = "non robust")
plt.loglog(range(len(sing_vals_robust[0])), sing_rob , label = "robust")
plt.legend(loc = "upper right")

# %%
plt.semilogy(range(len(sing_vals[0])), sing_non , label = "non robust")
plt.semilogy(range(len(sing_vals_robust[0])), sing_rob , label = "robust")
plt.legend(loc = "upper right")

# %%
plt.plot(range(len(sing_vals[0])), sing_non , label = "non robust")
plt.plot(range(len(sing_vals_robust[0])), sing_rob , label = "robust")
plt.legend(loc = "upper right")

# %%
def all_plots_layer_k(k):
    norm_factor_non = sing_vals[k][0]
    print("-----NORM FACTOR NON---")
    print(norm_factor_non)
    sing_non = sing_vals[k]/norm_factor_non
    norm_factor_rob = sing_vals_robust[k][0]
    print("-----NORM FACTOR ROB---")
    print(norm_factor_rob)
    sing_rob = sing_vals_robust[k]/norm_factor_rob
    plt.loglog(range(len(sing_vals[k])), sing_non , label = "non robust")
    plt.loglog(range(len(sing_vals_robust[k])), sing_rob , label = "robust")
    plt.legend(loc = "upper right")
    plt.show()
    plt.semilogy(range(len(sing_vals[k])), sing_non , label = "non robust")
    plt.semilogy(range(len(sing_vals_robust[k])), sing_rob , label = "robust")
    plt.legend(loc = "upper right")
    plt.show()
    plt.plot(range(len(sing_vals[k])), sing_non , label = "non robust")
    plt.plot(range(len(sing_vals_robust[k])), sing_rob , label = "robust")
    plt.legend(loc = "upper right")
    plt.show()

# %%
num_layers = len(sing_vals)

# %%
num_layers

# %%
for k in range(8):
    print(k)
    print("-----------")
    all_plots_layer_k(k)
    print("-----------")

# %%
for k in range(8):
    print(k)
    print("-----------")
    all_plots_layer_k(k)
    print("-----------")
